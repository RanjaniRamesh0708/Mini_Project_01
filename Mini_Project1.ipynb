# %% [markdown]
# <a href="https://colab.research.google.com/github/RanjaniRamesh0708/Mini_Project_01/blob/main/Mini_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
api_key="pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl"

url=f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-07&api_key={api_key}"

# %%
import requests

response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
data=response.json()

# %%
data
# Out:
# {'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-07&end_date=2024-01-13&detailed=false&api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl',
#   'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2023-12-26&end_date=2024-01-01&detailed=false&api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl',
#   'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-07&detailed=false&api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#  'element_count': 109,
#  'near_earth_objects': {'2024-01-02': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2415949?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '2415949',
#     'neo_reference_id': '2415949',
#     'name': '415949 (2001 XY10)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2415949',
#     'absolute_magnitude_h': 19.37,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3552670883,
#       'estimated_diameter_max': 0.7944013596},
#      'meters': {'estimated_diameter_min': 355.267088298,
#       'estimated_diameter_max': 794.4013596028},
#      'miles': {'estimated_diameter_min': 0.2207526659,
#       'estimated_diameter_max': 0.4936179672},
#      'feet': {'estimated_diameter_min': 1165.5744739718,
#       'estimated_diameter_max': 2606.3037566394}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 13:14',
#       'epoch_date_close_approach': 1704201240000,
#       'relative_velocity': {'kilometers_per_second': '15.8905264223',
#        'kilometers_per_hour': '57205.8951204341',
#        'miles_per_hour': '35545.5185541386'},
#       'miss_distance': {'astronomical': '0.3372535274',
#        'lunar': '131.1916221586',
#        'kilometers': '50452409.349026638',
#        'miles': '31349673.4658100844'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3160747?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3160747',
#     'neo_reference_id': '3160747',
#     'name': '(2003 SR84)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3160747',
#     'absolute_magnitude_h': 26.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0167708462,
#       'estimated_diameter_max': 0.0375007522},
#      'meters': {'estimated_diameter_min': 16.7708462163,
#       'estimated_diameter_max': 37.5007521798},
#      'miles': {'estimated_diameter_min': 0.0104209175,
#       'estimated_diameter_max': 0.0233018799},
#      'feet': {'estimated_diameter_min': 55.0224631002,
#       'estimated_diameter_max': 123.0339677816}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 22:45',
#       'epoch_date_close_approach': 1704235500000,
#       'relative_velocity': {'kilometers_per_second': '10.7191818981',
#        'kilometers_per_hour': '38589.054833182',
#        'miles_per_hour': '23977.7379878735'},
#       'miss_distance': {'astronomical': '0.1323425924',
#        'lunar': '51.4812684436',
#        'kilometers': '19798169.933318188',
#        'miles': '12302012.3446714744'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3309828?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3309828',
#     'neo_reference_id': '3309828',
#     'name': '(2005 YQ96)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3309828',
#     'absolute_magnitude_h': 20.62,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1997813652,
#       'estimated_diameter_max': 0.4467247133},
#      'meters': {'estimated_diameter_min': 199.78136523,
#       'estimated_diameter_max': 446.7247132921},
#      'miles': {'estimated_diameter_min': 0.1241383467,
#       'estimated_diameter_max': 0.2775817818},
#      'feet': {'estimated_diameter_min': 655.4506943013,
#       'estimated_diameter_max': 1465.6323083572}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 19:42',
#       'epoch_date_close_approach': 1704224520000,
#       'relative_velocity': {'kilometers_per_second': '15.6702817644',
#        'kilometers_per_hour': '56413.0143519451',
#        'miles_per_hour': '35052.8532788517'},
#       'miss_distance': {'astronomical': '0.1670126223',
#        'lunar': '64.9679100747',
#        'kilometers': '24984732.559194501',
#        'miles': '15524792.9180700738'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3457842?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3457842',
#     'neo_reference_id': '3457842',
#     'name': '(2009 HC21)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3457842',
#     'absolute_magnitude_h': 22.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1010543415,
#       'estimated_diameter_max': 0.2259643771},
#      'meters': {'estimated_diameter_min': 101.054341542,
#       'estimated_diameter_max': 225.9643771094},
#      'miles': {'estimated_diameter_min': 0.0627922373,
#       'estimated_diameter_max': 0.140407711},
#      'feet': {'estimated_diameter_min': 331.5431259047,
#       'estimated_diameter_max': 741.3529669956}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 12:06',
#       'epoch_date_close_approach': 1704197160000,
#       'relative_velocity': {'kilometers_per_second': '6.0808661718',
#        'kilometers_per_hour': '21891.1182185894',
#        'miles_per_hour': '13602.2895397674'},
#       'miss_distance': {'astronomical': '0.4920511029',
#        'lunar': '191.4078790281',
#        'kilometers': '73609796.924990823',
#        'miles': '45739006.8632584374'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3553062?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3553062',
#     'neo_reference_id': '3553062',
#     'name': '(2010 XA11)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3553062',
#     'absolute_magnitude_h': 26.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0160160338,
#       'estimated_diameter_max': 0.0358129403},
#      'meters': {'estimated_diameter_min': 16.0160337979,
#       'estimated_diameter_max': 35.8129403019},
#      'miles': {'estimated_diameter_min': 0.0099518989,
#       'estimated_diameter_max': 0.0222531225},
#      'feet': {'estimated_diameter_min': 52.5460443254,
#       'estimated_diameter_max': 117.4965270602}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 15:31',
#       'epoch_date_close_approach': 1704209460000,
#       'relative_velocity': {'kilometers_per_second': '8.7413828775',
#        'kilometers_per_hour': '31468.9783588978',
#        'miles_per_hour': '19553.5993586163'},
#       'miss_distance': {'astronomical': '0.2358022486',
#        'lunar': '91.7270747054',
#        'kilometers': '35275514.131770482',
#        'miles': '21919188.0752253716'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3591616?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3591616',
#     'neo_reference_id': '3591616',
#     'name': '(2011 YP10)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3591616',
#     'absolute_magnitude_h': 23.94,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0433066885,
#       'estimated_diameter_max': 0.0968366995},
#      'meters': {'estimated_diameter_min': 43.3066885476,
#       'estimated_diameter_max': 96.8366994728},
#      'miles': {'estimated_diameter_min': 0.0269095204,
#       'estimated_diameter_max': 0.0601715168},
#      'feet': {'estimated_diameter_min': 142.0823160544,
#       'estimated_diameter_max': 317.7057170982}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 12:59',
#       'epoch_date_close_approach': 1704200340000,
#       'relative_velocity': {'kilometers_per_second': '5.8070023218',
#        'kilometers_per_hour': '20905.2083584121',
#        'miles_per_hour': '12989.6834935922'},
#       'miss_distance': {'astronomical': '0.0704899554',
#        'lunar': '27.4205926506',
#        'kilometers': '10545147.184234998',
#        'miles': '6552450.6191110524'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3608936?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3608936',
#     'neo_reference_id': '3608936',
#     'name': '(2012 SD22)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3608936',
#     'absolute_magnitude_h': 20.05,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2597496533,
#       'estimated_diameter_max': 0.580817882},
#      'meters': {'estimated_diameter_min': 259.7496533301,
#       'estimated_diameter_max': 580.817881978},
#      'miles': {'estimated_diameter_min': 0.1614009018,
#       'estimated_diameter_max': 0.3609033881},
#      'feet': {'estimated_diameter_min': 852.1970526314,
#       'estimated_diameter_max': 1905.5705399087}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 13:50',
#       'epoch_date_close_approach': 1704203400000,
#       'relative_velocity': {'kilometers_per_second': '11.0227943004',
#        'kilometers_per_hour': '39682.059481597',
#        'miles_per_hour': '24656.8885706623'},
#       'miss_distance': {'astronomical': '0.1644228854',
#        'lunar': '63.9605024206',
#        'kilometers': '24597313.435094098',
#        'miles': '15284061.8372026324'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3795154?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3795154',
#     'neo_reference_id': '3795154',
#     'name': '(2017 YD8)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3795154',
#     'absolute_magnitude_h': 21.87,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1123453177,
#       'estimated_diameter_max': 0.2512117673},
#      'meters': {'estimated_diameter_min': 112.3453176718,
#       'estimated_diameter_max': 251.2117672679},
#      'miles': {'estimated_diameter_min': 0.0698081224,
#       'estimated_diameter_max': 0.156095707},
#      'feet': {'estimated_diameter_min': 368.5870120303,
#       'estimated_diameter_max': 824.1856145234}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 18:22',
#       'epoch_date_close_approach': 1704219720000,
#       'relative_velocity': {'kilometers_per_second': '18.9936426332',
#        'kilometers_per_hour': '68377.1134793652',
#        'miles_per_hour': '42486.8792061089'},
#       'miss_distance': {'astronomical': '0.2012574006',
#        'lunar': '78.2891288334',
#        'kilometers': '30107678.451496722',
#        'miles': '18708043.8862378836'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3842680?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3842680',
#     'neo_reference_id': '3842680',
#     'name': '(2019 KK5)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3842680',
#     'absolute_magnitude_h': 22.79,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0735453089,
#       'estimated_diameter_max': 0.1644523102},
#      'meters': {'estimated_diameter_min': 73.545308935,
#       'estimated_diameter_max': 164.452310205},
#      'miles': {'estimated_diameter_min': 0.0456989222,
#       'estimated_diameter_max': 0.1021858964},
#      'feet': {'estimated_diameter_min': 241.2903913664,
#       'estimated_diameter_max': 539.5417174129}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 21:21',
#       'epoch_date_close_approach': 1704230460000,
#       'relative_velocity': {'kilometers_per_second': '20.8331302779',
#        'kilometers_per_hour': '74999.2690004519',
#        'miles_per_hour': '46601.6291186419'},
#       'miss_distance': {'astronomical': '0.0260972745',
#        'lunar': '10.1518397805',
#        'kilometers': '3904096.678005315',
#        'miles': '2425893.185550747'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2613286?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '2613286',
#     'neo_reference_id': '2613286',
#     'name': '613286 (2005 YQ96)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2613286',
#     'absolute_magnitude_h': 20.63,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1988634532,
#       'estimated_diameter_max': 0.4446721997},
#      'meters': {'estimated_diameter_min': 198.8634532359,
#       'estimated_diameter_max': 444.6721996757},
#      'miles': {'estimated_diameter_min': 0.1235679828,
#       'estimated_diameter_max': 0.2763064094},
#      'feet': {'estimated_diameter_min': 652.4391719144,
#       'estimated_diameter_max': 1458.8983395842}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 19:42',
#       'epoch_date_close_approach': 1704224520000,
#       'relative_velocity': {'kilometers_per_second': '15.6702896005',
#        'kilometers_per_hour': '56413.0425616862',
#        'miles_per_hour': '35052.8708072878'},
#       'miss_distance': {'astronomical': '0.16701304',
#        'lunar': '64.96807256',
#        'kilometers': '24984795.0462248',
#        'miles': '15524831.74571024'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54338714?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54338714',
#     'neo_reference_id': '54338714',
#     'name': '(2023 AW)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54338714',
#     'absolute_magnitude_h': 25.68,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0194336768,
#       'estimated_diameter_max': 0.0434550225},
#      'meters': {'estimated_diameter_min': 19.433676839,
#       'estimated_diameter_max': 43.4550224647},
#      'miles': {'estimated_diameter_min': 0.0120755232,
#       'estimated_diameter_max': 0.0270016908},
#      'feet': {'estimated_diameter_min': 63.7587843204,
#       'estimated_diameter_max': 142.5689759032}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 11:42',
#       'epoch_date_close_approach': 1704195720000,
#       'relative_velocity': {'kilometers_per_second': '5.3000317604',
#        'kilometers_per_hour': '19080.1143374717',
#        'miles_per_hour': '11855.6410448585'},
#       'miss_distance': {'astronomical': '0.1086400025',
#        'lunar': '42.2609609725',
#        'kilometers': '16252312.970794675',
#        'miles': '10098718.996229515'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54415081?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54415081',
#     'neo_reference_id': '54415081',
#     'name': '(2023 XZ4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54415081',
#     'absolute_magnitude_h': 24.05,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0411675457,
#       'estimated_diameter_max': 0.0920534307},
#      'meters': {'estimated_diameter_min': 41.1675457307,
#       'estimated_diameter_max': 92.0534307207},
#      'miles': {'estimated_diameter_min': 0.0255803191,
#       'estimated_diameter_max': 0.0571993323},
#      'feet': {'estimated_diameter_min': 135.0641307351,
#       'estimated_diameter_max': 302.0125776456}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 15:23',
#       'epoch_date_close_approach': 1704208980000,
#       'relative_velocity': {'kilometers_per_second': '11.3259084311',
#        'kilometers_per_hour': '40773.2703521008',
#        'miles_per_hour': '25334.9245696151'},
#       'miss_distance': {'astronomical': '0.1449999147',
#        'lunar': '56.4049668183',
#        'kilometers': '21691678.389301689',
#        'miles': '13478583.9408697482'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54417653?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54417653',
#     'neo_reference_id': '54417653',
#     'name': '(2023 YR)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54417653',
#     'absolute_magnitude_h': 24.9,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0278326768,
#       'estimated_diameter_max': 0.0622357573},
#      'meters': {'estimated_diameter_min': 27.8326768072,
#       'estimated_diameter_max': 62.2357573367},
#      'miles': {'estimated_diameter_min': 0.0172944182,
#       'estimated_diameter_max': 0.0386714948},
#      'feet': {'estimated_diameter_min': 91.3145593761,
#       'estimated_diameter_max': 204.1855621004}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 03:18',
#       'epoch_date_close_approach': 1704165480000,
#       'relative_velocity': {'kilometers_per_second': '12.2195715368',
#        'kilometers_per_hour': '43990.4575325894',
#        'miles_per_hour': '27333.9595707359'},
#       'miss_distance': {'astronomical': '0.0115640803',
#        'lunar': '4.4984272367',
#        'kilometers': '1729961.781388961',
#        'miles': '1074948.4049352218'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54418497?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54418497',
#     'neo_reference_id': '54418497',
#     'name': '(2024 AA)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54418497',
#     'absolute_magnitude_h': 27.41,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0087610261,
#       'estimated_diameter_max': 0.01959025},
#      'meters': {'estimated_diameter_min': 8.7610261497,
#       'estimated_diameter_max': 19.5902500233},
#      'miles': {'estimated_diameter_min': 0.0054438476,
#       'estimated_diameter_max': 0.0121728132},
#      'feet': {'estimated_diameter_min': 28.7435250329,
#       'estimated_diameter_max': 64.2724758865}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 16:39',
#       'epoch_date_close_approach': 1704213540000,
#       'relative_velocity': {'kilometers_per_second': '21.4321092699',
#        'kilometers_per_hour': '77155.5933716609',
#        'miles_per_hour': '47941.4852258523'},
#       'miss_distance': {'astronomical': '0.0040814207',
#        'lunar': '1.5876726523',
#        'kilometers': '610571.843293909',
#        'miles': '379391.7507935842'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54418796?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54418796',
#     'neo_reference_id': '54418796',
#     'name': '(2022 OY78)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54418796',
#     'absolute_magnitude_h': 26.38,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0140784543,
#       'estimated_diameter_max': 0.0314803809},
#      'meters': {'estimated_diameter_min': 14.0784543386,
#       'estimated_diameter_max': 31.4803809193},
#      'miles': {'estimated_diameter_min': 0.0087479433,
#       'estimated_diameter_max': 0.0195609958},
#      'feet': {'estimated_diameter_min': 46.1891561324,
#       'estimated_diameter_max': 103.2820929354}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 21:11',
#       'epoch_date_close_approach': 1704229860000,
#       'relative_velocity': {'kilometers_per_second': '8.8314719331',
#        'kilometers_per_hour': '31793.2989592959',
#        'miles_per_hour': '19755.1195672358'},
#       'miss_distance': {'astronomical': '0.1173407628',
#        'lunar': '45.6455567292',
#        'kilometers': '17553928.179055236',
#        'miles': '10907505.1827288168'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54419485?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54419485',
#     'neo_reference_id': '54419485',
#     'name': '(2024 AQ1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54419485',
#     'absolute_magnitude_h': 23.72,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0479242116,
#       'estimated_diameter_max': 0.1071617948},
#      'meters': {'estimated_diameter_min': 47.924211552,
#       'estimated_diameter_max': 107.1617947985},
#      'miles': {'estimated_diameter_min': 0.0297787153,
#       'estimated_diameter_max': 0.0665872316},
#      'feet': {'estimated_diameter_min': 157.2316702284,
#       'estimated_diameter_max': 351.5807028466}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 08:59',
#       'epoch_date_close_approach': 1704185940000,
#       'relative_velocity': {'kilometers_per_second': '15.469545141',
#        'kilometers_per_hour': '55690.3625074711',
#        'miles_per_hour': '34603.8255258228'},
#       'miss_distance': {'astronomical': '0.0438286898',
#        'lunar': '17.0493603322',
#        'kilometers': '6556678.638970726',
#        'miles': '4074131.1862829788'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54419601?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54419601',
#     'neo_reference_id': '54419601',
#     'name': '(2024 AA2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54419601',
#     'absolute_magnitude_h': 20.54,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2072788434,
#       'estimated_diameter_max': 0.4634895841},
#      'meters': {'estimated_diameter_min': 207.2788433771,
#       'estimated_diameter_max': 463.4895840887},
#      'miles': {'estimated_diameter_min': 0.1287970622,
#       'estimated_diameter_max': 0.2879989864},
#      'feet': {'estimated_diameter_min': 680.0487205053,
#       'estimated_diameter_max': 1520.6351670615}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 10:17',
#       'epoch_date_close_approach': 1704190620000,
#       'relative_velocity': {'kilometers_per_second': '16.000245467',
#        'kilometers_per_hour': '57600.8836810697',
#        'miles_per_hour': '35790.9490850513'},
#       'miss_distance': {'astronomical': '0.1924771023',
#        'lunar': '74.8735927947',
#        'kilometers': '28794164.527852101',
#        'miles': '17891864.1808409538'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54420153?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54420153',
#     'neo_reference_id': '54420153',
#     'name': '(2024 AR3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54420153',
#     'absolute_magnitude_h': 23.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0506471459,
#       'estimated_diameter_max': 0.1132504611},
#      'meters': {'estimated_diameter_min': 50.6471458835,
#       'estimated_diameter_max': 113.2504610618},
#      'miles': {'estimated_diameter_min': 0.0314706677,
#       'estimated_diameter_max': 0.0703705522},
#      'feet': {'estimated_diameter_min': 166.1651821003,
#       'estimated_diameter_max': 371.5566426699}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 18:03',
#       'epoch_date_close_approach': 1704218580000,
#       'relative_velocity': {'kilometers_per_second': '13.0433070531',
#        'kilometers_per_hour': '46955.9053910434',
#        'miles_per_hour': '29176.5735470069'},
#       'miss_distance': {'astronomical': '0.0526643224',
#        'lunar': '20.4864214136',
#        'kilometers': '7878470.456033288',
#        'miles': '4895454.5361358544'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54421393?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54421393',
#     'neo_reference_id': '54421393',
#     'name': '(2024 BK1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54421393',
#     'absolute_magnitude_h': 24.49,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0336166921,
#       'estimated_diameter_max': 0.0751692087},
#      'meters': {'estimated_diameter_min': 33.6166921158,
#       'estimated_diameter_max': 75.1692087496},
#      'miles': {'estimated_diameter_min': 0.0208884376,
#       'estimated_diameter_max': 0.0467079664},
#      'feet': {'estimated_diameter_min': 110.2909881611,
#       'estimated_diameter_max': 246.6181468339}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 05:49',
#       'epoch_date_close_approach': 1704174540000,
#       'relative_velocity': {'kilometers_per_second': '5.8516481506',
#        'kilometers_per_hour': '21065.9333422733',
#        'miles_per_hour': '13089.5517481475'},
#       'miss_distance': {'astronomical': '0.2431104304',
#        'lunar': '94.5699574256',
#        'kilometers': '36368802.562623248',
#        'miles': '22598526.0048389024'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2669051?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '2669051',
#     'neo_reference_id': '2669051',
#     'name': '669051 (2012 SD22)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2669051',
#     'absolute_magnitude_h': 20.08,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2561857545,
#       'estimated_diameter_max': 0.5728487619},
#      'meters': {'estimated_diameter_min': 256.1857544793,
#       'estimated_diameter_max': 572.8487618827},
#      'miles': {'estimated_diameter_min': 0.1591863984,
#       'estimated_diameter_max': 0.355951608},
#      'feet': {'estimated_diameter_min': 840.5044707257,
#       'estimated_diameter_max': 1879.4251319352}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 13:50',
#       'epoch_date_close_approach': 1704203400000,
#       'relative_velocity': {'kilometers_per_second': '11.0227939149',
#        'kilometers_per_hour': '39682.0580935237',
#        'miles_per_hour': '24656.8877081676'},
#       'miss_distance': {'astronomical': '0.1644228604',
#        'lunar': '63.9604926956',
#        'kilometers': '24597309.695147348',
#        'miles': '15284059.5133074824'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54444997?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54444997',
#     'neo_reference_id': '54444997',
#     'name': '(2024 KY)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54444997',
#     'absolute_magnitude_h': 26.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0133215567,
#       'estimated_diameter_max': 0.0297879063},
#      'meters': {'estimated_diameter_min': 13.3215566698,
#       'estimated_diameter_max': 29.7879062798},
#      'miles': {'estimated_diameter_min': 0.008277629,
#       'estimated_diameter_max': 0.0185093411},
#      'feet': {'estimated_diameter_min': 43.7058959846,
#       'estimated_diameter_max': 97.7293544391}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 18:13',
#       'epoch_date_close_approach': 1704219180000,
#       'relative_velocity': {'kilometers_per_second': '6.2809825165',
#        'kilometers_per_hour': '22611.5370594138',
#        'miles_per_hour': '14049.9297911674'},
#       'miss_distance': {'astronomical': '0.2348125113',
#        'lunar': '91.3420668957',
#        'kilometers': '35127451.539830931',
#        'miles': '21827186.2467756078'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54445206?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54445206',
#     'neo_reference_id': '54445206',
#     'name': '(2024 KJ1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54445206',
#     'absolute_magnitude_h': 26.21,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0152249185,
#       'estimated_diameter_max': 0.0340439527},
#      'meters': {'estimated_diameter_min': 15.2249185036,
#       'estimated_diameter_max': 34.043952726},
#      'miles': {'estimated_diameter_min': 0.0094603228,
#       'estimated_diameter_max': 0.0211539249},
#      'feet': {'estimated_diameter_min': 49.9505216234,
#       'estimated_diameter_max': 111.6927618614}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 11:41',
#       'epoch_date_close_approach': 1704195660000,
#       'relative_velocity': {'kilometers_per_second': '4.9851096001',
#        'kilometers_per_hour': '17946.3945602822',
#        'miles_per_hour': '11151.1916644154'},
#       'miss_distance': {'astronomical': '0.107160298',
#        'lunar': '41.685355922',
#        'kilometers': '16030952.32936526',
#        'miles': '9961171.871790188'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-01-01': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3724393?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3724393',
#     'neo_reference_id': '3724393',
#     'name': '(2015 OD22)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3724393',
#     'absolute_magnitude_h': 21.21,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.152249185,
#       'estimated_diameter_max': 0.3404395273},
#      'meters': {'estimated_diameter_min': 152.249185036,
#       'estimated_diameter_max': 340.4395272595},
#      'miles': {'estimated_diameter_min': 0.0946032284,
#       'estimated_diameter_max': 0.2115392495},
#      'feet': {'estimated_diameter_min': 499.5052162336,
#       'estimated_diameter_max': 1116.9276186141}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-01',
#       'close_approach_date_full': '2024-Jan-01 11:58',
#       'epoch_date_close_approach': 1704110280000,
#       'relative_velocity': {'kilometers_per_second': '25.3931645932',
#        'kilometers_per_hour': '91415.3925356518',
#        'miles_per_hour': '56801.969878611'},
#       'miss_distance': {'astronomical': '0.4372881787',
#        'lunar': '170.1051015143',
#        'kilometers': '65417380.109699369',
#        'miles': '40648475.1053305322'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3797695?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3797695',
#     'neo_reference_id': '3797695',
#     'name': '(2018 BA)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3797695',
#     'absolute_magnitude_h': 25.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.02658,
#       'estimated_diameter_max': 0.0594346868},
#      'meters': {'estimated_diameter_min': 26.58,
#       'estimated_diameter_max': 59.4346868419},
#      'miles': {'estimated_diameter_min': 0.0165160412,
#       'estimated_diameter_max': 0.0369309908},
#      'feet': {'estimated_diameter_min': 87.2047272,
#       'estimated_diameter_max': 194.9956979785}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-01',
#       'close_approach_date_full': '2024-Jan-01 08:13',
#       'epoch_date_close_approach': 1704096780000,
#       'relative_velocity': {'kilometers_per_second': '16.7051869184',
#        'kilometers_per_hour': '60138.6729062958',
#        'miles_per_hour': '37367.8326178036'},
#       'miss_distance': {'astronomical': '0.3961064439',
#        'lunar': '154.0854066771',
#        'kilometers': '59256680.300714493',
#        'miles': '36820393.7545182834'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3986699?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3986699',
#     'neo_reference_id': '3986699',
#     'name': '(2020 BC)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3986699',
#     'absolute_magnitude_h': 26.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0152951935,
#       'estimated_diameter_max': 0.0342010925},
#      'meters': {'estimated_diameter_min': 15.2951935344,
#       'estimated_diameter_max': 34.201092472},
#      'miles': {'estimated_diameter_min': 0.0095039897,
#       'estimated_diameter_max': 0.021251567},
#      'feet': {'estimated_diameter_min': 50.1810827555,
#       'estimated_diameter_max': 112.2083122258}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-01',
#       'close_approach_date_full': '2024-Jan-01 16:14',
#       'epoch_date_close_approach': 1704125640000,
#       'relative_velocity': {'kilometers_per_second': '8.3141771772',
#        'kilometers_per_hour': '29931.0378379052',
#        'miles_per_hour': '18597.9829276695'},
#       'miss_distance': {'astronomical': '0.1675870266',
#        'lunar': '65.1913533474',
#        'kilometers': '25070662.218993342',
#        'miles': '15578187.1327464396'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54200446?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54200446',
#     'neo_reference_id': '54200446',
#     'name': '(2021 SG2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54200446',
#     'absolute_magnitude_h': 25.54,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0207278843,
#       'estimated_diameter_max': 0.0463489584},
#      'meters': {'estimated_diameter_min': 20.7278843377,
#       'estimated_diameter_max': 46.3489584089},
#      'miles': {'estimated_diameter_min': 0.0128797062,
#       'estimated_diameter_max': 0.0287998986},
#      'feet': {'estimated_diameter_min': 68.0048720505,
#       'estimated_diameter_max': 152.0635167062}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-01',
#       'close_approach_date_full': '2024-Jan-01 21:39',
#       'epoch_date_close_approach': 1704145140000,
#       'relative_velocity': {'kilometers_per_second': '19.2601228725',
#        'kilometers_per_hour': '69336.4423409755',
#        'miles_per_hour': '43082.96885348'},
#       'miss_distance': {'astronomical': '0.4799164554',
#        'lunar': '186.6875011506',
#        'kilometers': '71794479.505789998',
#        'miles': '44611020.9243700524'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235663?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54235663',
#     'neo_reference_id': '54235663',
#     'name': '(2022 AO2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235663',
#     'absolute_magnitude_h': 24.19,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0385971268,
#       'estimated_diameter_max': 0.0863057993},
#      'meters': {'estimated_diameter_min': 38.5971267955,
#       'estimated_diameter_max': 86.3057992509},
#      'miles': {'estimated_diameter_min': 0.0239831353,
#       'estimated_diameter_max': 0.0536279208},
#      'feet': {'estimated_diameter_min': 126.6309974757,
#       'estimated_diameter_max': 283.1555184142}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-01',
#       'close_approach_date_full': '2024-Jan-01 23:44',
#       'epoch_date_close_approach': 1704152640000,
#       'relative_velocity': {'kilometers_per_second': '19.5135931126',
#        'kilometers_per_hour': '70248.9352052905',
#        'miles_per_hour': '43649.9564335318'},
#       'miss_distance': {'astronomical': '0.3679836493',
#        'lunar': '143.1456395777',
#        'kilometers': '55049570.130106991',
#        'miles': '34206216.7155028358'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54418438?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54418438',
#     'neo_reference_id': '54418438',
#     'name': '(2023 YR1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54418438',
#     'absolute_magnitude_h': 25.68,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0194336768,
#       'estimated_diameter_max': 0.0434550225},
#      'meters': {'estimated_diameter_min': 19.433676839,
#       'estimated_diameter_max': 43.4550224647},
#      'miles': {'estimated_diameter_min': 0.0120755232,
#       'estimated_diameter_max': 0.0270016908},
#      'feet': {'estimated_diameter_min': 63.7587843204,
#       'estimated_diameter_max': 142.5689759032}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-01',
#       'close_approach_date_full': '2024-Jan-01 02:48',
#       'epoch_date_close_approach': 1704077280000,
#       'relative_velocity': {'kilometers_per_second': '13.2957757989',
#        'kilometers_per_hour': '47864.7928761016',
#        'miles_per_hour': '29741.3208845977'},
#       'miss_distance': {'astronomical': '0.0166083198',
#        'lunar': '6.4606364022',
#        'kilometers': '2484569.266358826',
#        'miles': '1543839.7533147588'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54418650?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54418650',
#     'neo_reference_id': '54418650',
#     'name': '(2023 YY1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54418650',
#     'absolute_magnitude_h': 25.77,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0186446818,
#       'estimated_diameter_max': 0.041690776},
#      'meters': {'estimated_diameter_min': 18.644681832,
#       'estimated_diameter_max': 41.6907759952},
#      'miles': {'estimated_diameter_min': 0.0115852646,
#       'estimated_diameter_max': 0.0259054392},
#      'feet': {'estimated_diameter_min': 61.1702179417,
#       'estimated_diameter_max': 136.7807655161}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-01',
#       'close_approach_date_full': '2024-Jan-01 20:09',
#       'epoch_date_close_approach': 1704139740000,
#       'relative_velocity': {'kilometers_per_second': '6.4760794463',
#        'kilometers_per_hour': '23313.886006764',
#        'miles_per_hour': '14486.3421134807'},
#       'miss_distance': {'astronomical': '0.0271321169',
#        'lunar': '10.5543934741',
#        'kilometers': '4058906.896831003',
#        'miles': '2522087.7949257214'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54419698?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54419698',
#     'neo_reference_id': '54419698',
#     'name': '(2024 AV2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54419698',
#     'absolute_magnitude_h': 26.64,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0124897854,
#       'estimated_diameter_max': 0.0279280092},
#      'meters': {'estimated_diameter_min': 12.4897854067,
#       'estimated_diameter_max': 27.9280091938},
#      'miles': {'estimated_diameter_min': 0.0077607904,
#       'estimated_diameter_max': 0.017353655},
#      'feet': {'estimated_diameter_min': 40.9769875538,
#       'estimated_diameter_max': 91.6273296835}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-01',
#       'close_approach_date_full': '2024-Jan-01 02:47',
#       'epoch_date_close_approach': 1704077220000,
#       'relative_velocity': {'kilometers_per_second': '8.0634346109',
#        'kilometers_per_hour': '29028.3645991597',
#        'miles_per_hour': '18037.0968810723'},
#       'miss_distance': {'astronomical': '0.0097074099',
#        'lunar': '3.7761824511',
#        'kilometers': '1452207.844256913',
#        'miles': '902360.1114268794'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54421384?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54421384',
#     'neo_reference_id': '54421384',
#     'name': '(2024 AA6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54421384',
#     'absolute_magnitude_h': 25.12,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0251509837,
#       'estimated_diameter_max': 0.0562393094},
#      'meters': {'estimated_diameter_min': 25.1509837491,
#       'estimated_diameter_max': 56.239309364},
#      'miles': {'estimated_diameter_min': 0.0156280919,
#       'estimated_diameter_max': 0.0349454759},
#      'feet': {'estimated_diameter_min': 82.5163535234,
#       'estimated_diameter_max': 184.5121757337}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-01',
#       'close_approach_date_full': '2024-Jan-01 12:30',
#       'epoch_date_close_approach': 1704112200000,
#       'relative_velocity': {'kilometers_per_second': '7.1243393888',
#        'kilometers_per_hour': '25647.6217998182',
#        'miles_per_hour': '15936.4347788926'},
#       'miss_distance': {'astronomical': '0.0491415516',
#        'lunar': '19.1160635724',
#        'kilometers': '7351471.447855092',
#        'miles': '4567992.5370685896'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54513047?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54513047',
#     'neo_reference_id': '54513047',
#     'name': '(2025 AB)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54513047',
#     'absolute_magnitude_h': 27.13,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0099667824,
#       'estimated_diameter_max': 0.022286403},
#      'meters': {'estimated_diameter_min': 9.9667823997,
#       'estimated_diameter_max': 22.2864029626},
#      'miles': {'estimated_diameter_min': 0.0061930695,
#       'estimated_diameter_max': 0.0138481245},
#      'feet': {'estimated_diameter_min': 32.6994183682,
#       'estimated_diameter_max': 73.118122296}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-01',
#       'close_approach_date_full': '2024-Jan-01 11:34',
#       'epoch_date_close_approach': 1704108840000,
#       'relative_velocity': {'kilometers_per_second': '7.7572149549',
#        'kilometers_per_hour': '27925.9738377584',
#        'miles_per_hour': '17352.1141326894'},
#       'miss_distance': {'astronomical': '0.1583792654',
#        'lunar': '61.6095342406',
#        'kilometers': '23693200.756004698',
#        'miles': '14722272.2689449124'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': True,
#     'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54513047?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'}],
#   '2024-01-04': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2450293?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '2450293',
#     'neo_reference_id': '2450293',
#     'name': '450293 (2004 LV3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2450293',
#     'absolute_magnitude_h': 18.83,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4555698523,
#       'estimated_diameter_max': 1.0186851583},
#      'meters': {'estimated_diameter_min': 455.5698523357,
#       'estimated_diameter_max': 1018.6851583223},
#      'miles': {'estimated_diameter_min': 0.2830778947,
#       'estimated_diameter_max': 0.6329814155},
#      'feet': {'estimated_diameter_min': 1494.6517943372,
#       'estimated_diameter_max': 3342.14301483}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-04',
#       'close_approach_date_full': '2024-Jan-04 13:59',
#       'epoch_date_close_approach': 1704376740000,
#       'relative_velocity': {'kilometers_per_second': '23.7178883208',
#        'kilometers_per_hour': '85384.3979548105',
#        'miles_per_hour': '53054.5443847543'},
#       'miss_distance': {'astronomical': '0.2515406075',
#        'lunar': '97.8492963175',
#        'kilometers': '37629939.100506025',
#        'miles': '23382159.911892145'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3541505?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3541505',
#     'neo_reference_id': '3541505',
#     'name': '(2010 PJ)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3541505',
#     'absolute_magnitude_h': 22.14,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0992098919,
#       'estimated_diameter_max': 0.2218400624},
#      'meters': {'estimated_diameter_min': 99.2098919421,
#       'estimated_diameter_max': 221.8400624229},
#      'miles': {'estimated_diameter_min': 0.0616461498,
#       'estimated_diameter_max': 0.1378449814},
#      'feet': {'estimated_diameter_min': 325.4917818793,
#       'estimated_diameter_max': 727.8217503997}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-04',
#       'close_approach_date_full': '2024-Jan-04 13:32',
#       'epoch_date_close_approach': 1704375120000,
#       'relative_velocity': {'kilometers_per_second': '18.4122352237',
#        'kilometers_per_hour': '66284.046805343',
#        'miles_per_hour': '41186.3289719088'},
#       'miss_distance': {'astronomical': '0.325882928',
#        'lunar': '126.768458992',
#        'kilometers': '48751391.89816336',
#        'miles': '30292710.233879968'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3759758?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3759758',
# ...
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 00:39',
#       'epoch_date_close_approach': 1704587940000,
#       'relative_velocity': {'kilometers_per_second': '17.5905759574',
#        'kilometers_per_hour': '63326.0734468031',
#        'miles_per_hour': '39348.3593592094'},
#       'miss_distance': {'astronomical': '0.191766701',
#        'lunar': '74.597246689',
#        'kilometers': '28687890.00652687',
#        'miles': '17825828.255416006'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3520662?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3520662',
#     'neo_reference_id': '3520662',
#     'name': '(2010 JR34)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3520662',
#     'absolute_magnitude_h': 27.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0076657557,
#       'estimated_diameter_max': 0.0171411509},
#      'meters': {'estimated_diameter_min': 7.6657557353,
#       'estimated_diameter_max': 17.1411509231},
#      'miles': {'estimated_diameter_min': 0.0047632783,
#       'estimated_diameter_max': 0.0106510141},
#      'feet': {'estimated_diameter_min': 25.1501180466,
#       'estimated_diameter_max': 56.2373735944}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 11:45',
#       'epoch_date_close_approach': 1704627900000,
#       'relative_velocity': {'kilometers_per_second': '10.5972841382',
#        'kilometers_per_hour': '38150.2228974764',
#        'miles_per_hour': '23705.0648887125'},
#       'miss_distance': {'astronomical': '0.203565311',
#        'lunar': '79.186905979',
#        'kilometers': '30452936.93148757',
#        'miles': '18922577.557645666'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3596030?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3596030',
#     'neo_reference_id': '3596030',
#     'name': '(2012 BV13)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3596030',
#     'absolute_magnitude_h': 22.29,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0925880583,
#       'estimated_diameter_max': 0.2070331923},
#      'meters': {'estimated_diameter_min': 92.5880583366,
#       'estimated_diameter_max': 207.0331923453},
#      'miles': {'estimated_diameter_min': 0.0575315344,
#       'estimated_diameter_max': 0.1286444218},
#      'feet': {'estimated_diameter_min': 303.766605313,
#       'estimated_diameter_max': 679.2427787741}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 09:14',
#       'epoch_date_close_approach': 1704618840000,
#       'relative_velocity': {'kilometers_per_second': '18.7982461783',
#        'kilometers_per_hour': '67673.6862419358',
#        'miles_per_hour': '42049.7968762739'},
#       'miss_distance': {'astronomical': '0.476653263',
#        'lunar': '185.418119307',
#        'kilometers': '71306312.87334981',
#        'miles': '44307688.244694978'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3843476?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '3843476',
#     'neo_reference_id': '3843476',
#     'name': '(2019 PJ)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3843476',
#     'absolute_magnitude_h': 23.78,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0466181437,
#       'estimated_diameter_max': 0.1042413384},
#      'meters': {'estimated_diameter_min': 46.618143739,
#       'estimated_diameter_max': 104.2413383852},
#      'miles': {'estimated_diameter_min': 0.0289671626,
#       'estimated_diameter_max': 0.0647725447},
#      'feet': {'estimated_diameter_min': 152.9466707045,
#       'estimated_diameter_max': 341.9991526276}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 15:55',
#       'epoch_date_close_approach': 1704642900000,
#       'relative_velocity': {'kilometers_per_second': '14.3972065058',
#        'kilometers_per_hour': '51829.9434207299',
#        'miles_per_hour': '32205.1112327307'},
#       'miss_distance': {'astronomical': '0.0248646998',
#        'lunar': '9.6723682222',
#        'kilometers': '3719706.128269426',
#        'miles': '2311318.2108570388'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54100190?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54100190',
#     'neo_reference_id': '54100190',
#     'name': '(2020 XA5)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54100190',
#     'absolute_magnitude_h': 24.29,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0368599699,
#       'estimated_diameter_max': 0.0824213984},
#      'meters': {'estimated_diameter_min': 36.8599699314,
#       'estimated_diameter_max': 82.4213984152},
#      'miles': {'estimated_diameter_min': 0.0229037164,
#       'estimated_diameter_max': 0.0512142668},
#      'feet': {'estimated_diameter_min': 120.9316637498,
#       'estimated_diameter_max': 270.4114207767}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 01:00',
#       'epoch_date_close_approach': 1704589200000,
#       'relative_velocity': {'kilometers_per_second': '8.2454774127',
#        'kilometers_per_hour': '29683.7186858648',
#        'miles_per_hour': '18444.3084245586'},
#       'miss_distance': {'astronomical': '0.142752665',
#        'lunar': '55.530786685',
#        'kilometers': '21355494.62082355',
#        'miles': '13269689.03372299'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54151575?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54151575',
#     'neo_reference_id': '54151575',
#     'name': '(2021 LA)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54151575',
#     'absolute_magnitude_h': 23.84,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0453476699,
#       'estimated_diameter_max': 0.1014004725},
#      'meters': {'estimated_diameter_min': 45.3476698997,
#       'estimated_diameter_max': 101.400472517},
#      'miles': {'estimated_diameter_min': 0.028177727,
#       'estimated_diameter_max': 0.063007313},
#      'feet': {'estimated_diameter_min': 148.7784493137,
#       'estimated_diameter_max': 332.6787262525}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 05:11',
#       'epoch_date_close_approach': 1704604260000,
#       'relative_velocity': {'kilometers_per_second': '24.9091695738',
#        'kilometers_per_hour': '89673.010465549',
#        'miles_per_hour': '55719.3214195518'},
#       'miss_distance': {'astronomical': '0.4791922828',
#        'lunar': '186.4057980092',
#        'kilometers': '71686144.827317636',
#        'miles': '44543704.8766539368'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54212701?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54212701',
#     'neo_reference_id': '54212701',
#     'name': '(2021 UH2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54212701',
#     'absolute_magnitude_h': 25.13,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0250354255,
#       'estimated_diameter_max': 0.0559809132},
#      'meters': {'estimated_diameter_min': 25.0354254756,
#       'estimated_diameter_max': 55.980913209},
#      'miles': {'estimated_diameter_min': 0.0155562874,
#       'estimated_diameter_max': 0.034784916},
#      'feet': {'estimated_diameter_min': 82.1372253173,
#       'estimated_diameter_max': 183.6644192927}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 03:01',
#       'epoch_date_close_approach': 1704596460000,
#       'relative_velocity': {'kilometers_per_second': '4.9687502105',
#        'kilometers_per_hour': '17887.5007576928',
#        'miles_per_hour': '11114.5973458008'},
#       'miss_distance': {'astronomical': '0.1645356081',
#        'lunar': '64.0043515509',
#        'kilometers': '24614176.510914747',
#        'miles': '15294540.0666356286'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54418496?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54418496',
#     'neo_reference_id': '54418496',
#     'name': '(2023 YV1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54418496',
#     'absolute_magnitude_h': 23.68,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0488151892,
#       'estimated_diameter_max': 0.1091540813},
#      'meters': {'estimated_diameter_min': 48.8151891662,
#       'estimated_diameter_max': 109.1540813101},
#      'miles': {'estimated_diameter_min': 0.0303323429,
#       'estimated_diameter_max': 0.0678251807},
#      'feet': {'estimated_diameter_min': 160.154825224,
#       'estimated_diameter_max': 358.1170761255}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 02:19',
#       'epoch_date_close_approach': 1704593940000,
#       'relative_velocity': {'kilometers_per_second': '8.120493377',
#        'kilometers_per_hour': '29233.776157356',
#        'miles_per_hour': '18164.7316351082'},
#       'miss_distance': {'astronomical': '0.0564841975',
#        'lunar': '21.9723528275',
#        'kilometers': '8449915.634659325',
#        'miles': '5250534.104875685'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54418797?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54418797',
#     'neo_reference_id': '54418797',
#     'name': '(2024 AM)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54418797',
#     'absolute_magnitude_h': 27.83,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0072202956,
#       'estimated_diameter_max': 0.0161450717},
#      'meters': {'estimated_diameter_min': 7.2202955766,
#       'estimated_diameter_max': 16.1450717269},
#      'miles': {'estimated_diameter_min': 0.0044864823,
#       'estimated_diameter_max': 0.0100320794},
#      'feet': {'estimated_diameter_min': 23.6886345394,
#       'estimated_diameter_max': 52.9693971244}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 12:20',
#       'epoch_date_close_approach': 1704630000000,
#       'relative_velocity': {'kilometers_per_second': '9.023354683',
#        'kilometers_per_hour': '32484.0768586214',
#        'miles_per_hour': '20184.3420902917'},
#       'miss_distance': {'astronomical': '0.0080840728',
#        'lunar': '3.1447043192',
#        'kilometers': '1209360.071804936',
#        'miles': '751461.5028866768'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': True,
#     'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54418797?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54419021?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54419021',
#     'neo_reference_id': '54419021',
#     'name': '(2024 AW)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54419021',
#     'absolute_magnitude_h': 25.53,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0208235599,
#       'estimated_diameter_max': 0.0465628955},
#      'meters': {'estimated_diameter_min': 20.8235599047,
#       'estimated_diameter_max': 46.5628954805},
#      'miles': {'estimated_diameter_min': 0.0129391562,
#       'estimated_diameter_max': 0.0289328329},
#      'feet': {'estimated_diameter_min': 68.3187682778,
#       'estimated_diameter_max': 152.7654100083}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 13:36',
#       'epoch_date_close_approach': 1704634560000,
#       'relative_velocity': {'kilometers_per_second': '8.495992761',
#        'kilometers_per_hour': '30585.5739394365',
#        'miles_per_hour': '19004.6862069793'},
#       'miss_distance': {'astronomical': '0.0286110782',
#        'lunar': '11.1297094198',
#        'kilometers': '4280156.357123434',
#        'miles': '2659565.8346100292'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54419611?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54419611',
#     'neo_reference_id': '54419611',
#     'name': '(2024 AL2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54419611',
#     'absolute_magnitude_h': 27.38,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0088829042,
#       'estimated_diameter_max': 0.0198627775},
#      'meters': {'estimated_diameter_min': 8.8829041639,
#       'estimated_diameter_max': 19.8627775481},
#      'miles': {'estimated_diameter_min': 0.005519579,
#       'estimated_diameter_max': 0.0123421539},
#      'feet': {'estimated_diameter_min': 29.1433872971,
#       'estimated_diameter_max': 65.1665950909}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 09:32',
#       'epoch_date_close_approach': 1704619920000,
#       'relative_velocity': {'kilometers_per_second': '6.6495962837',
#        'kilometers_per_hour': '23938.5466214872',
#        'miles_per_hour': '14874.4819271124'},
#       'miss_distance': {'astronomical': '0.010003857',
#        'lunar': '3.891500373',
#        'kilometers': '1496555.69898459',
#        'miles': '929916.590543742'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54514905?api_key=pSkxtrhuACyq0C94X4ccYlDiktflE8apWoWIdiDl'},
#     'id': '54514905',
#     'neo_reference_id': '54514905',
#     'name': '(2025 AK2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54514905',
#     'absolute_magnitude_h': 21.74,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1192765246,
#       'estimated_diameter_max': 0.2667104172},
#      'meters': {'estimated_diameter_min': 119.2765246442,
#       'estimated_diameter_max': 266.7104172244},
#      'miles': {'estimated_diameter_min': 0.0741149734,
#       'estimated_diameter_max': 0.1657261187},
#      'feet': {'estimated_diameter_min': 391.3271931138,
#       'estimated_diameter_max': 875.0342052466}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 23:11',
#       'epoch_date_close_approach': 1704669060000,
#       'relative_velocity': {'kilometers_per_second': '18.3152326904',
#        'kilometers_per_hour': '65934.8376853835',
#        'miles_per_hour': '40969.3440051206'},
#       'miss_distance': {'astronomical': '0.1889423676',
#        'lunar': '73.4985809964',
#        'kilometers': '28265375.745717012',
#        'miles': '17563290.0678062856'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}]}}

# %%
import requests
from datetime import datetime
asteroids = []
target = 10000
url  = f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-08&api_key={api_key}"

while len(asteroids) < target:
  response = requests.get(url)
  data = response.json()
  details = data['near_earth_objects']
  for date, asteroids_details in details.items():
    for ast in asteroids_details:
      asteroids.append(dict(
          id = int(ast['id']),
          name = ast['name'],
          neo_reference_id = int(ast['neo_reference_id']),
          absolute_magnitude_h = float(ast['absolute_magnitude_h']),
          estimated_dia_man_km = float(ast['estimated_diameter']['kilometers']['estimated_diameter_max']),
          is_potentially_hazardous_asteroid = ast['is_potentially_hazardous_asteroid'],
          close_approach_date = ast['close_approach_data'][0]['close_approach_date'],
          relative_velocity_kmph= float(ast['close_approach_data'][0]['relative_velocity']['kilometers_per_hour']),
          astronomical_distance = float(ast['close_approach_data'][0]['miss_distance']['astronomical']),
          miss_distance_km = float(ast['close_approach_data'][0]['miss_distance']['kilometers']),
          miss_distance_lunar = float(ast['close_approach_data'][0]['miss_distance']['lunar']),
          orbiting_body = ast['close_approach_data'][0]['orbiting_body'],
          estimated_dia_min = float(ast['estimated_diameter']['kilometers']['estimated_diameter_min'])))

      if len(asteroids) >= target:
        break
    if len(asteroids) >= target:
      break
  url = data['links']['next']

# %%
asteroids
# Out:
# [{'id': 2415949,
#   'name': '415949 (2001 XY10)',
#   'neo_reference_id': 2415949,
#   'absolute_magnitude_h': 19.37,
#   'estimated_dia_man_km': 0.7944013596,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 57205.8951204341,
#   'astronomical_distance': 0.3372535274,
#   'miss_distance_km': 50452409.349026635,
#   'miss_distance_lunar': 131.1916221586,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.3552670883},
#  {'id': 3160747,
#   'name': '(2003 SR84)',
#   'neo_reference_id': 3160747,
#   'absolute_magnitude_h': 26.0,
#   'estimated_dia_man_km': 0.0375007522,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 38589.054833182,
#   'astronomical_distance': 0.1323425924,
#   'miss_distance_km': 19798169.933318187,
#   'miss_distance_lunar': 51.4812684436,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0167708462},
#  {'id': 3309828,
#   'name': '(2005 YQ96)',
#   'neo_reference_id': 3309828,
#   'absolute_magnitude_h': 20.62,
#   'estimated_dia_man_km': 0.4467247133,
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 56413.0143519451,
#   'astronomical_distance': 0.1670126223,
#   'miss_distance_km': 24984732.5591945,
#   'miss_distance_lunar': 64.9679100747,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1997813652},
#  {'id': 3457842,
#   'name': '(2009 HC21)',
#   'neo_reference_id': 3457842,
#   'absolute_magnitude_h': 22.1,
#   'estimated_dia_man_km': 0.2259643771,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 21891.1182185894,
#   'astronomical_distance': 0.4920511029,
#   'miss_distance_km': 73609796.92499082,
#   'miss_distance_lunar': 191.4078790281,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1010543415},
#  {'id': 3553062,
#   'name': '(2010 XA11)',
#   'neo_reference_id': 3553062,
#   'absolute_magnitude_h': 26.1,
#   'estimated_dia_man_km': 0.0358129403,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 31468.9783588978,
#   'astronomical_distance': 0.2358022486,
#   'miss_distance_km': 35275514.131770484,
#   'miss_distance_lunar': 91.7270747054,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0160160338},
#  {'id': 3591616,
#   'name': '(2011 YP10)',
#   'neo_reference_id': 3591616,
#   'absolute_magnitude_h': 23.94,
#   'estimated_dia_man_km': 0.0968366995,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 20905.2083584121,
#   'astronomical_distance': 0.0704899554,
#   'miss_distance_km': 10545147.184234997,
#   'miss_distance_lunar': 27.4205926506,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0433066885},
#  {'id': 3608936,
#   'name': '(2012 SD22)',
#   'neo_reference_id': 3608936,
#   'absolute_magnitude_h': 20.05,
#   'estimated_dia_man_km': 0.580817882,
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 39682.059481597,
#   'astronomical_distance': 0.1644228854,
#   'miss_distance_km': 24597313.4350941,
#   'miss_distance_lunar': 63.9605024206,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.2597496533},
#  {'id': 3795154,
#   'name': '(2017 YD8)',
#   'neo_reference_id': 3795154,
#   'absolute_magnitude_h': 21.87,
#   'estimated_dia_man_km': 0.2512117673,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 68377.1134793652,
#   'astronomical_distance': 0.2012574006,
#   'miss_distance_km': 30107678.45149672,
#   'miss_distance_lunar': 78.2891288334,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1123453177},
#  {'id': 3842680,
#   'name': '(2019 KK5)',
#   'neo_reference_id': 3842680,
#   'absolute_magnitude_h': 22.79,
#   'estimated_dia_man_km': 0.1644523102,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 74999.2690004519,
#   'astronomical_distance': 0.0260972745,
#   'miss_distance_km': 3904096.678005315,
#   'miss_distance_lunar': 10.1518397805,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0735453089},
#  {'id': 2613286,
#   'name': '613286 (2005 YQ96)',
#   'neo_reference_id': 2613286,
#   'absolute_magnitude_h': 20.63,
#   'estimated_dia_man_km': 0.4446721997,
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 56413.0425616862,
#   'astronomical_distance': 0.16701304,
#   'miss_distance_km': 24984795.0462248,
#   'miss_distance_lunar': 64.96807256,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1988634532},
#  {'id': 54338714,
#   'name': '(2023 AW)',
#   'neo_reference_id': 54338714,
#   'absolute_magnitude_h': 25.68,
#   'estimated_dia_man_km': 0.0434550225,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 19080.1143374717,
#   'astronomical_distance': 0.1086400025,
#   'miss_distance_km': 16252312.970794676,
#   'miss_distance_lunar': 42.2609609725,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0194336768},
#  {'id': 54415081,
#   'name': '(2023 XZ4)',
#   'neo_reference_id': 54415081,
#   'absolute_magnitude_h': 24.05,
#   'estimated_dia_man_km': 0.0920534307,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 40773.2703521008,
#   'astronomical_distance': 0.1449999147,
#   'miss_distance_km': 21691678.389301687,
#   'miss_distance_lunar': 56.4049668183,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0411675457},
#  {'id': 54417653,
#   'name': '(2023 YR)',
#   'neo_reference_id': 54417653,
#   'absolute_magnitude_h': 24.9,
#   'estimated_dia_man_km': 0.0622357573,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 43990.4575325894,
#   'astronomical_distance': 0.0115640803,
#   'miss_distance_km': 1729961.781388961,
#   'miss_distance_lunar': 4.4984272367,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0278326768},
#  {'id': 54418497,
#   'name': '(2024 AA)',
#   'neo_reference_id': 54418497,
#   'absolute_magnitude_h': 27.41,
#   'estimated_dia_man_km': 0.01959025,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 77155.5933716609,
#   'astronomical_distance': 0.0040814207,
#   'miss_distance_km': 610571.843293909,
#   'miss_distance_lunar': 1.5876726523,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0087610261},
#  {'id': 54418796,
#   'name': '(2022 OY78)',
#   'neo_reference_id': 54418796,
#   'absolute_magnitude_h': 26.38,
#   'estimated_dia_man_km': 0.0314803809,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 31793.2989592959,
#   'astronomical_distance': 0.1173407628,
#   'miss_distance_km': 17553928.179055236,
#   'miss_distance_lunar': 45.6455567292,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0140784543},
#  {'id': 54419485,
#   'name': '(2024 AQ1)',
#   'neo_reference_id': 54419485,
#   'absolute_magnitude_h': 23.72,
#   'estimated_dia_man_km': 0.1071617948,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 55690.3625074711,
#   'astronomical_distance': 0.0438286898,
#   'miss_distance_km': 6556678.638970726,
#   'miss_distance_lunar': 17.0493603322,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0479242116},
#  {'id': 54419601,
#   'name': '(2024 AA2)',
#   'neo_reference_id': 54419601,
#   'absolute_magnitude_h': 20.54,
#   'estimated_dia_man_km': 0.4634895841,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 57600.8836810697,
#   'astronomical_distance': 0.1924771023,
#   'miss_distance_km': 28794164.5278521,
#   'miss_distance_lunar': 74.8735927947,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.2072788434},
#  {'id': 54420153,
#   'name': '(2024 AR3)',
#   'neo_reference_id': 54420153,
#   'absolute_magnitude_h': 23.6,
#   'estimated_dia_man_km': 0.1132504611,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 46955.9053910434,
#   'astronomical_distance': 0.0526643224,
#   'miss_distance_km': 7878470.456033288,
#   'miss_distance_lunar': 20.4864214136,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0506471459},
#  {'id': 54421393,
#   'name': '(2024 BK1)',
#   'neo_reference_id': 54421393,
#   'absolute_magnitude_h': 24.49,
#   'estimated_dia_man_km': 0.0751692087,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 21065.9333422733,
#   'astronomical_distance': 0.2431104304,
#   'miss_distance_km': 36368802.56262325,
#   'miss_distance_lunar': 94.5699574256,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0336166921},
#  {'id': 2669051,
#   'name': '669051 (2012 SD22)',
#   'neo_reference_id': 2669051,
#   'absolute_magnitude_h': 20.08,
#   'estimated_dia_man_km': 0.5728487619,
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 39682.0580935237,
#   'astronomical_distance': 0.1644228604,
#   'miss_distance_km': 24597309.695147347,
#   'miss_distance_lunar': 63.9604926956,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.2561857545},
#  {'id': 54444997,
#   'name': '(2024 KY)',
#   'neo_reference_id': 54444997,
#   'absolute_magnitude_h': 26.5,
#   'estimated_dia_man_km': 0.0297879063,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 22611.5370594138,
#   'astronomical_distance': 0.2348125113,
#   'miss_distance_km': 35127451.53983093,
#   'miss_distance_lunar': 91.3420668957,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0133215567},
#  {'id': 54445206,
#   'name': '(2024 KJ1)',
#   'neo_reference_id': 54445206,
#   'absolute_magnitude_h': 26.21,
#   'estimated_dia_man_km': 0.0340439527,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-02',
#   'relative_velocity_kmph': 17946.3945602822,
#   'astronomical_distance': 0.107160298,
#   'miss_distance_km': 16030952.32936526,
#   'miss_distance_lunar': 41.685355922,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0152249185},
#  {'id': 3724393,
#   'name': '(2015 OD22)',
#   'neo_reference_id': 3724393,
#   'absolute_magnitude_h': 21.21,
#   'estimated_dia_man_km': 0.3404395273,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-01',
#   'relative_velocity_kmph': 91415.3925356518,
#   'astronomical_distance': 0.4372881787,
#   'miss_distance_km': 65417380.10969937,
#   'miss_distance_lunar': 170.1051015143,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.152249185},
#  {'id': 3797695,
#   'name': '(2018 BA)',
#   'neo_reference_id': 3797695,
#   'absolute_magnitude_h': 25.0,
#   'estimated_dia_man_km': 0.0594346868,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-01',
#   'relative_velocity_kmph': 60138.6729062958,
#   'astronomical_distance': 0.3961064439,
#   'miss_distance_km': 59256680.30071449,
#   'miss_distance_lunar': 154.0854066771,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.02658},
#  {'id': 3986699,
#   'name': '(2020 BC)',
#   'neo_reference_id': 3986699,
#   'absolute_magnitude_h': 26.2,
#   'estimated_dia_man_km': 0.0342010925,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-01',
#   'relative_velocity_kmph': 29931.0378379052,
#   'astronomical_distance': 0.1675870266,
#   'miss_distance_km': 25070662.218993343,
#   'miss_distance_lunar': 65.1913533474,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0152951935},
#  {'id': 54200446,
#   'name': '(2021 SG2)',
#   'neo_reference_id': 54200446,
#   'absolute_magnitude_h': 25.54,
#   'estimated_dia_man_km': 0.0463489584,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-01',
#   'relative_velocity_kmph': 69336.4423409755,
#   'astronomical_distance': 0.4799164554,
#   'miss_distance_km': 71794479.50579,
#   'miss_distance_lunar': 186.6875011506,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0207278843},
#  {'id': 54235663,
#   'name': '(2022 AO2)',
#   'neo_reference_id': 54235663,
#   'absolute_magnitude_h': 24.19,
#   'estimated_dia_man_km': 0.0863057993,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-01',
#   'relative_velocity_kmph': 70248.9352052905,
#   'astronomical_distance': 0.3679836493,
#   'miss_distance_km': 55049570.13010699,
#   'miss_distance_lunar': 143.1456395777,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0385971268},
#  {'id': 54418438,
#   'name': '(2023 YR1)',
#   'neo_reference_id': 54418438,
#   'absolute_magnitude_h': 25.68,
#   'estimated_dia_man_km': 0.0434550225,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-01',
#   'relative_velocity_kmph': 47864.7928761016,
#   'astronomical_distance': 0.0166083198,
#   'miss_distance_km': 2484569.266358826,
#   'miss_distance_lunar': 6.4606364022,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0194336768},
#  {'id': 54418650,
#   'name': '(2023 YY1)',
#   'neo_reference_id': 54418650,
#   'absolute_magnitude_h': 25.77,
#   'estimated_dia_man_km': 0.041690776,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-01',
#   'relative_velocity_kmph': 23313.886006764,
#   'astronomical_distance': 0.0271321169,
#   'miss_distance_km': 4058906.896831003,
#   'miss_distance_lunar': 10.5543934741,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0186446818},
#  {'id': 54419698,
#   'name': '(2024 AV2)',
#   'neo_reference_id': 54419698,
#   'absolute_magnitude_h': 26.64,
#   'estimated_dia_man_km': 0.0279280092,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-01',
#   'relative_velocity_kmph': 29028.3645991597,
#   'astronomical_distance': 0.0097074099,
#   'miss_distance_km': 1452207.844256913,
#   'miss_distance_lunar': 3.7761824511,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0124897854},
#  {'id': 54421384,
#   'name': '(2024 AA6)',
#   'neo_reference_id': 54421384,
#   'absolute_magnitude_h': 25.12,
#   'estimated_dia_man_km': 0.0562393094,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-01',
#   'relative_velocity_kmph': 25647.6217998182,
#   'astronomical_distance': 0.0491415516,
#   'miss_distance_km': 7351471.447855092,
#   'miss_distance_lunar': 19.1160635724,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0251509837},
#  {'id': 54513047,
#   'name': '(2025 AB)',
#   'neo_reference_id': 54513047,
#   'absolute_magnitude_h': 27.13,
#   'estimated_dia_man_km': 0.022286403,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-01',
#   'relative_velocity_kmph': 27925.9738377584,
#   'astronomical_distance': 0.1583792654,
#   'miss_distance_km': 23693200.7560047,
#   'miss_distance_lunar': 61.6095342406,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0099667824},
#  {'id': 2450293,
#   'name': '450293 (2004 LV3)',
#   'neo_reference_id': 2450293,
#   'absolute_magnitude_h': 18.83,
#   'estimated_dia_man_km': 1.0186851583,
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_date': '2024-01-04',
#   'relative_velocity_kmph': 85384.3979548105,
#   'astronomical_distance': 0.2515406075,
#   'miss_distance_km': 37629939.10050602,
#   'miss_distance_lunar': 97.8492963175,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.4555698523},
#  {'id': 3541505,
#   'name': '(2010 PJ)',
#   'neo_reference_id': 3541505,
#   'absolute_magnitude_h': 22.14,
#   'estimated_dia_man_km': 0.2218400624,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-04',
#   'relative_velocity_kmph': 66284.046805343,
#   'astronomical_distance': 0.325882928,
#   'miss_distance_km': 48751391.89816336,
#   'miss_distance_lunar': 126.768458992,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0992098919},
#  {'id': 3759758,
#   'name': '(2016 SU2)',
#   'neo_reference_id': 3759758,
#   'absolute_magnitude_h': 27.6,
#   'estimated_dia_man_km': 0.0179489885,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-04',
#   'relative_velocity_kmph': 61645.9178601515,
#   'astronomical_distance': 0.1648175282,
#   'miss_distance_km': 24656351.157384936,
#   'miss_distance_lunar': 64.1140184698,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0080270317},
#  {'id': 54244177,
#   'name': '(2022 BR6)',
#   'neo_reference_id': 54244177,
#   'absolute_magnitude_h': 26.66,
#   'estimated_dia_man_km': 0.0276719637,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-04',
#   'relative_velocity_kmph': 73098.6130534572,
#   'astronomical_distance': 0.4542370391,
#   'miss_distance_km': 67952893.52446672,
#   'miss_distance_lunar': 176.6982082099,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0123752784},
#  {'id': 54377575,
#   'name': '(2023 QC2)',
#   'neo_reference_id': 54377575,
#   'absolute_magnitude_h': 26.1,
#   'estimated_dia_man_km': 0.0358129403,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-04',
#   'relative_velocity_kmph': 19363.5674240887,
#   'astronomical_distance': 0.4421869191,
#   'miss_distance_km': 66150221.23922232,
#   'miss_distance_lunar': 172.0107115299,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0160160338},
#  {'id': 54416724,
#   'name': '(2023 XX12)',
#   'neo_reference_id': 54416724,
#   'absolute_magnitude_h': 24.76,
#   'estimated_dia_man_km': 0.0663804174,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-04',
#   'relative_velocity_kmph': 24905.7058657695,
#   'astronomical_distance': 0.0568168249,
#   'miss_distance_km': 8499675.985202963,
#   'miss_distance_lunar': 22.1017448861,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0296862251},
#  {'id': 54416853,
#   'name': '(2023 XS13)',
#   'neo_reference_id': 54416853,
#   'absolute_magnitude_h': 24.27,
#   'estimated_dia_man_km': 0.0831840342,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-04',
#   'relative_velocity_kmph': 24856.6146233309,
#   'astronomical_distance': 0.1552920913,
#   'miss_distance_km': 23231366.08632553,
#   'miss_distance_lunar': 60.4086235157,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.037201031},
#  {'id': 54418649,
#   'name': '(2024 AD)',
#   'neo_reference_id': 54418649,
#   'absolute_magnitude_h': 28.76,
#   'estimated_dia_man_km': 0.0105205872,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-04',
#   'relative_velocity_kmph': 35641.5158026425,
#   'astronomical_distance': 0.0016221885,
#   'miss_distance_km': 242675.944338495,
#   'miss_distance_lunar': 0.6310313265,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0047049496},
#  {'id': 54419602,
#   'name': '(2024 AB2)',
#   'neo_reference_id': 54419602,
#   'absolute_magnitude_h': 26.83,
#   'estimated_dia_man_km': 0.0255882143,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-04',
#   'relative_velocity_kmph': 25213.574669802,
#   'astronomical_distance': 0.0049740667,
#   'miss_distance_km': 744109.783557929,
#   'miss_distance_lunar': 1.9349119463,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0114433973},
#  {'id': 54467128,
#   'name': '(2024 QT)',
#   'neo_reference_id': 54467128,
#   'absolute_magnitude_h': 27.93,
#   'estimated_dia_man_km': 0.0154184238,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-04',
#   'relative_velocity_kmph': 21162.834162253,
#   'astronomical_distance': 0.2794852184,
#   'miss_distance_km': 41810393.36912481,
#   'miss_distance_lunar': 108.7197499576,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0068953287},
#  {'id': 3154493,
#   'name': '(2003 JV14)',
#   'neo_reference_id': 3154493,
#   'absolute_magnitude_h': 21.39,
#   'estimated_dia_man_km': 0.3133574171,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 49177.1673871585,
#   'astronomical_distance': 0.2621610014,
#   'miss_distance_km': 39218727.406507015,
#   'miss_distance_lunar': 101.9806295446,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1401376972},
#  {'id': 3591759,
#   'name': '(2011 YE40)',
#   'neo_reference_id': 3591759,
#   'absolute_magnitude_h': 25.2,
#   'estimated_dia_man_km': 0.0542050786,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 47099.8219113461,
#   'astronomical_distance': 0.1185645923,
#   'miss_distance_km': 17737010.465498403,
#   'miss_distance_lunar': 46.1216264047,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0242412481},
#  {'id': 3595775,
#   'name': '(2012 AB11)',
#   'neo_reference_id': 3595775,
#   'absolute_magnitude_h': 22.32,
#   'estimated_dia_man_km': 0.2041925905,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 66101.0085197716,
#   'astronomical_distance': 0.2870697327,
#   'miss_distance_km': 42945020.55338935,
#   'miss_distance_lunar': 111.6701260203,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0913177026},
#  {'id': 3605578,
#   'name': '(2012 LJ2)',
#   'neo_reference_id': 3605578,
#   'absolute_magnitude_h': 21.7,
#   'estimated_dia_man_km': 0.2716689341,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 62605.7918647103,
#   'astronomical_distance': 0.4856779711,
#   'miss_distance_km': 72656389.98248155,
#   'miss_distance_lunar': 188.9287307579,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1214940408},
#  {'id': 3645001,
#   'name': '(2013 NT11)',
#   'neo_reference_id': 3645001,
#   'absolute_magnitude_h': 19.49,
#   'estimated_dia_man_km': 0.7516920875,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 136267.5931308216,
#   'astronomical_distance': 0.3878716833,
#   'miss_distance_km': 58024777.65499457,
#   'miss_distance_lunar': 150.8820848037,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.3361669212},
#  {'id': 3751529,
#   'name': '(2016 GZ215)',
#   'neo_reference_id': 3751529,
#   'absolute_magnitude_h': 21.08,
#   'estimated_dia_man_km': 0.3614431336,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 13412.6297084999,
#   'astronomical_distance': 0.3169592421,
#   'miss_distance_km': 47416427.49497433,
#   'miss_distance_lunar': 123.2971451769,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1616422833},
#  {'id': 3787600,
#   'name': '(2017 UJ2)',
#   'neo_reference_id': 3787600,
#   'absolute_magnitude_h': 30.9,
#   'estimated_dia_man_km': 0.0039268108,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 20392.71468415,
#   'astronomical_distance': 0.2789034507,
#   'miss_distance_km': 41723362.16037001,
#   'miss_distance_lunar': 108.4934423223,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0017561232},
#  {'id': 3789479,
#   'name': '(2017 WQ1)',
#   'neo_reference_id': 3789479,
#   'absolute_magnitude_h': 24.98,
#   'estimated_dia_man_km': 0.0599846292,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 77947.7941353121,
#   'astronomical_distance': 0.3928589898,
#   'miss_distance_km': 58770868.08443172,
#   'miss_distance_lunar': 152.8221470322,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0268259417},
#  {'id': 3837605,
#   'name': '(2019 AE3)',
#   'neo_reference_id': 3837605,
#   'absolute_magnitude_h': 27.4,
#   'estimated_dia_man_km': 0.0196806745,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 30643.8908800298,
#   'astronomical_distance': 0.219831404,
#   'miss_distance_km': 32886309.79750948,
#   'miss_distance_lunar': 85.514416156,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0088014652},
#  {'id': 3986746,
#   'name': '(2020 BG1)',
#   'neo_reference_id': 3986746,
#   'absolute_magnitude_h': 22.08,
#   'estimated_dia_man_km': 0.2280551997,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 30660.8552813021,
#   'astronomical_distance': 0.4392947647,
#   'miss_distance_km': 65717561.10127119,
#   'miss_distance_lunar': 170.8856634683,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1019893859},
#  {'id': 54048870,
#   'name': '(2020 OU)',
#   'neo_reference_id': 54048870,
#   'absolute_magnitude_h': 22.23,
#   'estimated_dia_man_km': 0.212833496,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 35815.2965269734,
#   'astronomical_distance': 0.3576520119,
#   'miss_distance_km': 53503979.18145465,
#   'miss_distance_lunar': 139.1266326291,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.095182033},
#  {'id': 54278142,
#   'name': '(2022 JM)',
#   'neo_reference_id': 54278142,
#   'absolute_magnitude_h': 28.8,
#   'estimated_dia_man_km': 0.0103285648,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 15135.7875736874,
#   'astronomical_distance': 0.1665503321,
#   'miss_distance_km': 24915574.929952625,
#   'miss_distance_lunar': 64.7880791869,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0046190746},
#  {'id': 54339170,
#   'name': '(2023 AE2)',
#   'neo_reference_id': 54339170,
#   'absolute_magnitude_h': 25.09,
#   'estimated_dia_man_km': 0.0570216761,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 40627.9359558418,
#   'astronomical_distance': 0.4160098355,
#   'miss_distance_km': 62234185.289850384,
#   'miss_distance_lunar': 161.8278260095,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0255008688},
#  {'id': 54382904,
#   'name': '(2023 RM9)',
#   'neo_reference_id': 54382904,
#   'absolute_magnitude_h': 22.63,
#   'estimated_dia_man_km': 0.1770271912,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 46687.637003535,
#   'astronomical_distance': 0.4276145672,
#   'miss_distance_km': 63970228.434091866,
#   'miss_distance_lunar': 166.3420666408,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0791689667},
#  {'id': 54407115,
#   'name': '(2023 WQ1)',
#   'neo_reference_id': 54407115,
#   'absolute_magnitude_h': 21.7,
#   'estimated_dia_man_km': 0.2716689341,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 21316.3863185218,
#   'astronomical_distance': 0.2215539291,
#   'miss_distance_km': 33143995.883491017,
#   'miss_distance_lunar': 86.1844784199,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1214940408},
#  {'id': 54415862,
#   'name': '(2023 XN7)',
#   'neo_reference_id': 54415862,
#   'absolute_magnitude_h': 21.91,
#   'estimated_dia_man_km': 0.2466266358,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 50245.145075255,
#   'astronomical_distance': 0.2425550851,
#   'miss_distance_km': 36285724.08862874,
#   'miss_distance_lunar': 94.3539281039,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1102947845},
#  {'id': 54419016,
#   'name': '(2024 AS)',
#   'neo_reference_id': 54419016,
#   'absolute_magnitude_h': 25.21,
#   'estimated_dia_man_km': 0.0539560289,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 26620.9107473446,
#   'astronomical_distance': 0.0621231269,
#   'miss_distance_km': 9293487.461979702,
#   'miss_distance_lunar': 24.1658963641,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0241298697},
#  {'id': 54419705,
#   'name': '(2024 AA3)',
#   'neo_reference_id': 54419705,
#   'absolute_magnitude_h': 25.76,
#   'estimated_dia_man_km': 0.0418832119,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 38651.4528346904,
#   'astronomical_distance': 0.0348077157,
#   'miss_distance_km': 5207160.128285559,
#   'miss_distance_lunar': 13.5402014073,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0187307418},
#  {'id': 54419812,
#   'name': '(2024 AH3)',
#   'neo_reference_id': 54419812,
#   'absolute_magnitude_h': 25.67,
#   'estimated_dia_man_km': 0.0436556017,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 35581.2855133506,
#   'astronomical_distance': 0.0179963637,
#   'miss_distance_km': 2692217.677265319,
#   'miss_distance_lunar': 7.0005854793,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0195233786},
#  {'id': 54419817,
#   'name': '(2024 AM3)',
#   'neo_reference_id': 54419817,
#   'absolute_magnitude_h': 26.6,
#   'estimated_dia_man_km': 0.0284472297,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 34700.8767701078,
#   'astronomical_distance': 0.0179149084,
#   'miss_distance_km': 2680032.137885108,
#   'miss_distance_lunar': 6.9688993676,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0127219879},
#  {'id': 54425076,
#   'name': '(2024 BB8)',
#   'neo_reference_id': 54425076,
#   'absolute_magnitude_h': 21.37,
#   'estimated_dia_man_km': 0.3162568776,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 43666.3832834038,
#   'astronomical_distance': 0.4646252744,
#   'miss_distance_km': 69506951.39840552,
#   'miss_distance_lunar': 180.7392317416,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1414343753},
#  {'id': 2668499,
#   'name': '668499 (2012 AB11)',
#   'neo_reference_id': 2668499,
#   'absolute_magnitude_h': 22.32,
#   'estimated_dia_man_km': 0.2041925905,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 66101.008470871,
#   'astronomical_distance': 0.2870697328,
#   'miss_distance_km': 42945020.56834914,
#   'miss_distance_lunar': 111.6701260592,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0913177026},
#  {'id': 2676480,
#   'name': '676480 (2016 GZ215)',
#   'neo_reference_id': 2676480,
#   'absolute_magnitude_h': 21.08,
#   'estimated_dia_man_km': 0.3614431336,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-03',
#   'relative_velocity_kmph': 13412.6295371653,
#   'astronomical_distance': 0.316959242,
#   'miss_distance_km': 47416427.48001454,
#   'miss_distance_lunar': 123.297145138,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1616422833},
#  {'id': 2304640,
#   'name': '304640 (2006 WW1)',
#   'neo_reference_id': 2304640,
#   'absolute_magnitude_h': 19.17,
#   'estimated_dia_man_km': 0.8710437698,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 82917.386474944,
#   'astronomical_distance': 0.3042250642,
#   'miss_distance_km': 45511421.604933254,
#   'miss_distance_lunar': 118.3435499738,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.3895426161},
#  {'id': 3102756,
#   'name': '(2002 AO11)',
#   'neo_reference_id': 3102756,
#   'absolute_magnitude_h': 23.05,
#   'estimated_dia_man_km': 0.1458948557,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 66352.9893943133,
#   'astronomical_distance': 0.4011389088,
#   'miss_distance_km': 60009526.330604255,
#   'miss_distance_lunar': 156.0430355232,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.065246163},
#  {'id': 3623521,
#   'name': '(2013 AK20)',
#   'neo_reference_id': 3623521,
#   'absolute_magnitude_h': 23.19,
#   'estimated_dia_man_km': 0.1367854737,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 33449.0167383958,
#   'astronomical_distance': 0.2658726974,
#   'miss_distance_km': 39773989.22219454,
#   'miss_distance_lunar': 103.4244792886,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0611723235},
#  {'id': 3630638,
#   'name': '(2013 EU9)',
#   'neo_reference_id': 3630638,
#   'absolute_magnitude_h': 21.66,
#   'estimated_dia_man_km': 0.2767196367,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 23244.7020210603,
#   'astronomical_distance': 0.4595500589,
#   'miss_distance_km': 68747709.96981454,
#   'miss_distance_lunar': 178.7649729121,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1237527837},
#  {'id': 3752775,
#   'name': '(2016 JX5)',
#   'neo_reference_id': 3752775,
#   'absolute_magnitude_h': 26.9,
#   'estimated_dia_man_km': 0.0247765013,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 47409.8201474422,
#   'astronomical_distance': 0.219641036,
#   'miss_distance_km': 32857831.15019332,
#   'miss_distance_lunar': 85.440363004,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0110803882},
#  {'id': 3780672,
#   'name': '(2017 PM26)',
#   'neo_reference_id': 3780672,
#   'absolute_magnitude_h': 21.28,
#   'estimated_dia_man_km': 0.3296400556,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 67006.5424308666,
#   'astronomical_distance': 0.2157438397,
#   'miss_distance_km': 32274818.88474144,
#   'miss_distance_lunar': 83.9243536433,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1474195145},
#  {'id': 3794988,
#   'name': '(2017 YZ1)',
#   'neo_reference_id': 3794988,
#   'absolute_magnitude_h': 20.43,
#   'estimated_dia_man_km': 0.4875733714,
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 44018.2595059564,
#   'astronomical_distance': 0.4823054753,
#   'miss_distance_km': 72151871.79421762,
#   'miss_distance_lunar': 187.6168298917,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.2180494405},
#  {'id': 54131589,
#   'name': '(2021 EU4)',
#   'neo_reference_id': 54131589,
#   'absolute_magnitude_h': 24.66,
#   'estimated_dia_man_km': 0.0695088301,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 48806.5481244749,
#   'astronomical_distance': 0.2906663653,
#   'miss_distance_km': 43483069.129521914,
#   'miss_distance_lunar': 113.0692161017,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0310852938},
#  {'id': 54162245,
#   'name': '(2021 MQ1)',
#   'neo_reference_id': 54162245,
#   'absolute_magnitude_h': 23.05,
#   'estimated_dia_man_km': 0.1458948557,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 77270.3508057131,
#   'astronomical_distance': 0.1358979668,
#   'miss_distance_km': 20330046.370610718,
#   'miss_distance_lunar': 52.8643090852,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.065246163},
#  {'id': 2591179,
#   'name': '591179 (2013 EU9)',
#   'neo_reference_id': 2591179,
#   'absolute_magnitude_h': 21.66,
#   'estimated_dia_man_km': 0.2767196367,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 23244.7048088382,
#   'astronomical_distance': 0.4595501104,
#   'miss_distance_km': 68747717.67410485,
#   'miss_distance_lunar': 178.7649929456,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1237527837},
#  {'id': 54212682,
#   'name': '(2021 UO1)',
#   'neo_reference_id': 54212682,
#   'absolute_magnitude_h': 28.03,
#   'estimated_dia_man_km': 0.0147244804,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 48600.390963496,
#   'astronomical_distance': 0.4175439216,
#   'miss_distance_km': 62463681.30280699,
#   'miss_distance_lunar': 162.4245855024,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0065849878},
#  {'id': 54373932,
#   'name': '(2023 MB3)',
#   'neo_reference_id': 54373932,
#   'absolute_magnitude_h': 30.0,
#   'estimated_dia_man_km': 0.0059434687,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 46861.3592628214,
#   'astronomical_distance': 0.3657282297,
#   'miss_distance_km': 54712164.16199074,
#   'miss_distance_lunar': 142.2682813533,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.002658},
#  {'id': 54397463,
#   'name': '(2023 UE4)',
#   'neo_reference_id': 54397463,
#   'absolute_magnitude_h': 21.68,
#   'estimated_dia_man_km': 0.2741826558,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 30474.7461624521,
#   'astronomical_distance': 0.2020846207,
#   'miss_distance_km': 30231428.81647791,
#   'miss_distance_lunar': 78.6109174523,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1226182113},
#  {'id': 54418498,
#   'name': '(2024 AC)',
#   'neo_reference_id': 54418498,
#   'absolute_magnitude_h': 25.5,
#   'estimated_dia_man_km': 0.0472106499,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 24436.4638807862,
#   'astronomical_distance': 0.0154698996,
#   'miss_distance_km': 2314264.029273852,
#   'miss_distance_lunar': 6.0177909444,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0211132445},
#  {'id': 54418648,
#   'name': '(2023 YX1)',
#   'neo_reference_id': 54418648,
#   'absolute_magnitude_h': 24.86,
#   'estimated_dia_man_km': 0.0633928065,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 51523.5339034366,
#   'astronomical_distance': 0.0259173986,
#   'miss_distance_km': 3877187.626500982,
#   'miss_distance_lunar': 10.0818680554,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0283501249},
#  {'id': 54419186,
#   'name': '(2024 AH1)',
#   'neo_reference_id': 54419186,
#   'absolute_magnitude_h': 25.84,
#   'estimated_dia_man_km': 0.0403682552,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 34732.8834290542,
#   'astronomical_distance': 0.0230037015,
#   'miss_distance_km': 3441304.746515805,
#   'miss_distance_lunar': 8.9484398835,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0180532326},
#  {'id': 54420155,
#   'name': '(2024 AV3)',
#   'neo_reference_id': 54420155,
#   'absolute_magnitude_h': 25.78,
#   'estimated_dia_man_km': 0.0414992243,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 49762.1209539445,
#   'astronomical_distance': 0.031246689,
#   'miss_distance_km': 4674438.11895243,
#   'miss_distance_lunar': 12.154962021,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0185590173},
#  {'id': 54421084,
#   'name': '(2024 BR)',
#   'neo_reference_id': 54421084,
#   'absolute_magnitude_h': 21.67,
#   'estimated_dia_man_km': 0.2754482254,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-06',
#   'relative_velocity_kmph': 68918.5793084036,
#   'astronomical_distance': 0.203790755,
#   'miss_distance_km': 30486662.87369185,
#   'miss_distance_lunar': 79.274603695,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1231841913},
#  {'id': 3387092,
#   'name': '(2007 SG11)',
#   'neo_reference_id': 3387092,
#   'absolute_magnitude_h': 22.68,
#   'estimated_dia_man_km': 0.1729975604,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-05',
#   'relative_velocity_kmph': 21130.5453762448,
#   'astronomical_distance': 0.279217138,
#   'miss_distance_km': 41770289.11229606,
#   'miss_distance_lunar': 108.615466682,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.077366861},
#  {'id': 3655366,
#   'name': '(2013 YD)',
#   'neo_reference_id': 3655366,
#   'absolute_magnitude_h': 23.6,
#   'estimated_dia_man_km': 0.1132504611,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-05',
#   'relative_velocity_kmph': 95388.94889847,
#   'astronomical_distance': 0.4134715606,
#   'miss_distance_km': 61854464.77133592,
#   'miss_distance_lunar': 160.8404370734,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0506471459},
#  {'id': 3759280,
#   'name': '(2016 RW19)',
#   'neo_reference_id': 3759280,
#   'absolute_magnitude_h': 20.97,
#   'estimated_dia_man_km': 0.3802243961,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-05',
#   'relative_velocity_kmph': 55636.6868556782,
#   'astronomical_distance': 0.3310608323,
#   'miss_distance_km': 49525995.352507204,
#   'miss_distance_lunar': 128.7826637647,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1700415193},
#  {'id': 3795150,
#   'name': '(2017 YA8)',
#   'neo_reference_id': 3795150,
#   'absolute_magnitude_h': 22.33,
#   'estimated_dia_man_km': 0.2032544107,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-05',
#   'relative_velocity_kmph': 74295.3517022466,
#   'astronomical_distance': 0.47281464,
#   'miss_distance_km': 70732063.0488168,
#   'miss_distance_lunar': 183.92489496,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0908981358},
#  {'id': 3989198,
#   'name': '(2020 BT8)',
#   'neo_reference_id': 3989198,
#   'absolute_magnitude_h': 22.66,
#   'estimated_dia_man_km': 0.1745982871,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-05',
#   'relative_velocity_kmph': 32809.7259574529,
#   'astronomical_distance': 0.4020460517,
#   'miss_distance_km': 60145232.97622988,
#   'miss_distance_lunar': 156.3959141113,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0780827277},
#  {'id': 54016989,
#   'name': '(2020 JB1)',
#   'neo_reference_id': 54016989,
#   'absolute_magnitude_h': 26.4,
#   'estimated_dia_man_km': 0.0311917671,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-05',
#   'relative_velocity_kmph': 29836.407506762,
#   'astronomical_distance': 0.195163435,
#   'miss_distance_km': 29196034.17788345,
#   'miss_distance_lunar': 75.918576215,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0139493823},
#  {'id': 54191244,
#   'name': '(2021 QC3)',
#   'neo_reference_id': 54191244,
#   'absolute_magnitude_h': 24.24,
#   'estimated_dia_man_km': 0.0843412394,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-05',
#   'relative_velocity_kmph': 65428.143420128,
#   'astronomical_distance': 0.4792718313,
#   'miss_distance_km': 71698045.11347933,
#   'miss_distance_lunar': 186.4367423757,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0377185489},
#  {'id': 54360724,
#   'name': '(2023 KF5)',
#   'neo_reference_id': 54360724,
#   'absolute_magnitude_h': 26.45,
#   'estimated_dia_man_km': 0.0304817558,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-05',
#   'relative_velocity_kmph': 51299.9383417686,
#   'astronomical_distance': 0.3682368165,
#   'miss_distance_km': 55087443.40398086,
#   'miss_distance_lunar': 143.2441216185,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0136318556},
#  {'id': 54376461,
#   'name': '(2023 OG5)',
#   'neo_reference_id': 54376461,
#   'absolute_magnitude_h': 24.2,
#   'estimated_dia_man_km': 0.0859092601,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-05',
#   'relative_velocity_kmph': 55324.8986595102,
#   'astronomical_distance': 0.4815497794,
#   'miss_distance_km': 72038821.29720987,
#   'miss_distance_lunar': 187.3228641866,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0384197891},
#  {'id': 54406858,
#   'name': '(2023 WX)',
#   'neo_reference_id': 54406858,
#   'absolute_magnitude_h': 21.41,
#   'estimated_dia_man_km': 0.310484539,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-05',
#   'relative_velocity_kmph': 59465.664578394,
#   'astronomical_distance': 0.3384902592,
#   'miss_distance_km': 50637421.7920679,
#   'miss_distance_lunar': 131.6727108288,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.138852907},
#  {'id': 54417658,
#   'name': '(2023 YX)',
#   'neo_reference_id': 54417658,
#   'absolute_magnitude_h': 23.34,
#   'estimated_dia_man_km': 0.1276556316,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-05',
#   'relative_velocity_kmph': 24550.9579392311,
#   'astronomical_distance': 0.1761707793,
#   'miss_distance_km': 26354773.33952009,
#   'miss_distance_lunar': 68.5304331477,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.057089334},
#  {'id': 54435948,
#   'name': '(2024 HY)',
#   'neo_reference_id': 54435948,
#   'absolute_magnitude_h': 23.67,
#   'estimated_dia_man_km': 0.1096579137,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-05',
#   'relative_velocity_kmph': 25849.764640261,
#   'astronomical_distance': 0.337303243,
#   'miss_distance_km': 50459846.69689241,
#   'miss_distance_lunar': 131.210961527,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0490405098},
#  {'id': 2168318,
#   'name': '168318 (1989 DA)',
#   'neo_reference_id': 2168318,
#   'absolute_magnitude_h': 18.91,
#   'estimated_dia_man_km': 0.9818383215,
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_date': '2024-01-08',
#   'relative_velocity_kmph': 31986.5321530766,
#   'astronomical_distance': 0.1176981136,
#   'miss_distance_km': 17607387.097578034,
#   'miss_distance_lunar': 45.7845661904,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.439091446},
#  {'id': 3102728,
#   'name': '(2002 AY1)',
#   'neo_reference_id': 3102728,
#   'absolute_magnitude_h': 20.85,
#   'estimated_dia_man_km': 0.4018277992,
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_date': '2024-01-08',
#   'relative_velocity_kmph': 62421.0107180472,
#   'astronomical_distance': 0.0387907687,
#   'miss_distance_km': 5803016.373182669,
#   'miss_distance_lunar': 15.0896090243,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1797028549},
#  {'id': 3599868,
#   'name': '(2012 DN31)',
#   'neo_reference_id': 3599868,
#   'absolute_magnitude_h': 24.0,
#   'estimated_dia_man_km': 0.0941976306,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-08',
#   'relative_velocity_kmph': 72972.4202450971,
#   'astronomical_distance': 0.438299464,
#   'miss_distance_km': 65568666.23654168,
#   'miss_distance_lunar': 170.498491496,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0421264611},
#  {'id': 3781448,
#   'name': '(2017 RJ15)',
#   'neo_reference_id': 3781448,
#   'absolute_magnitude_h': 21.85,
#   'estimated_dia_man_km': 0.2535362011,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-08',
#   'relative_velocity_kmph': 42691.0515194642,
#   'astronomical_distance': 0.2902198078,
#   'miss_distance_km': 43416265.07868939,
#   'miss_distance_lunar': 112.8955052342,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1133848361},
#  {'id': 3798020,
#   'name': '(2018 BW5)',
#   'neo_reference_id': 3798020,
#   'absolute_magnitude_h': 22.07,
#   'estimated_dia_man_km': 0.2291078547,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-08',
#   'relative_velocity_kmph': 1909.5781683299,
#   'astronomical_distance': 0.3704446777,
#   'miss_distance_km': 55417734.736756496,
#   'miss_distance_lunar': 144.1029796253,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1024601475},
#  {'id': 3825490,
#   'name': '(2018 MH7)',
#   'neo_reference_id': 3825490,
#   'absolute_magnitude_h': 26.1,
#   'estimated_dia_man_km': 0.0358129403,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-08',
#   'relative_velocity_kmph': 29893.7028024022,
#   'astronomical_distance': 0.2503022555,
#   'miss_distance_km': 37444684.27899578,
#   'miss_distance_lunar': 97.3675773895,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0160160338},
#  {'id': 3836410,
#   'name': '(2018 WA2)',
#   'neo_reference_id': 3836410,
#   'absolute_magnitude_h': 22.59,
#   'estimated_dia_man_km': 0.1803183724,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-08',
#   'relative_velocity_kmph': 34394.9468892197,
#   'astronomical_distance': 0.0830903048,
#   'miss_distance_km': 12430132.615730776,
#   'miss_distance_lunar': 32.3221285672,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0806408277},
#  {'id': 3873324,
#   'name': '(2019 TY)',
#   'neo_reference_id': 3873324,
#   'absolute_magnitude_h': 22.83,
#   'estimated_dia_man_km': 0.1614507173,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-01-08',
#   'relative_velocity_kmph': 64034.6295863063,
#   'astronomical_distance': 0.290437181,
#   'miss_distance_km': 43448783.64640447,
#   'miss_distance_lunar': 112.980063409,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0722029558},
#  {'id': 54232321,
#   'name': '(2022 AB)',
#   'neo_reference_id': 54232321,
# ...
#   'miss_distance_km': 45697860.35894646,
#   'miss_distance_lunar': 118.8283474867,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.2874451443},
#  {'id': 3840791,
#   'name': '(2019 GM1)',
#   'neo_reference_id': 3840791,
#   'absolute_magnitude_h': 27.25,
#   'estimated_dia_man_km': 0.0210882227,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 12445.5255007355,
#   'astronomical_distance': 0.1311391528,
#   'miss_distance_km': 19618137.932484537,
#   'miss_distance_lunar': 51.0131304392,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0094309399},
#  {'id': 54226416,
#   'name': '(2021 XT1)',
#   'neo_reference_id': 54226416,
#   'absolute_magnitude_h': 28.6,
#   'estimated_dia_man_km': 0.0113250461,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 72176.2716517384,
#   'astronomical_distance': 0.4810100214,
#   'miss_distance_km': 71958074.65009442,
#   'miss_distance_lunar': 187.1128983246,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0050647146},
#  {'id': 54235525,
#   'name': '(2022 AP1)',
#   'neo_reference_id': 54235525,
#   'absolute_magnitude_h': 28.39,
#   'estimated_dia_man_km': 0.0124749835,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 76416.7504491421,
#   'astronomical_distance': 0.3184562236,
#   'miss_distance_km': 47640372.73880373,
#   'miss_distance_lunar': 123.8794709804,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0055789822},
#  {'id': 54245592,
#   'name': '(2022 CB3)',
#   'neo_reference_id': 54245592,
#   'absolute_magnitude_h': 30.54,
#   'estimated_dia_man_km': 0.0046348958,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 84524.5201011124,
#   'astronomical_distance': 0.2206288196,
#   'miss_distance_km': 33005601.472774252,
#   'miss_distance_lunar': 85.8246108244,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0020727884},
#  {'id': 54358779,
#   'name': '(2023 JR4)',
#   'neo_reference_id': 54358779,
#   'absolute_magnitude_h': 26.84,
#   'estimated_dia_man_km': 0.0254706471,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 32347.9299347289,
#   'astronomical_distance': 0.4406102681,
#   'miss_distance_km': 65914357.607888944,
#   'miss_distance_lunar': 171.3973942909,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0113908197},
#  {'id': 54421915,
#   'name': '(2024 BE2)',
#   'neo_reference_id': 54421915,
#   'absolute_magnitude_h': 23.87,
#   'estimated_dia_man_km': 0.1000092059,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 30453.0246127931,
#   'astronomical_distance': 0.0855038216,
#   'miss_distance_km': 12791189.588219993,
#   'miss_distance_lunar': 33.2609866024,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0447254765},
#  {'id': 54423324,
#   'name': '(2024 BG5)',
#   'neo_reference_id': 54423324,
#   'absolute_magnitude_h': 21.27,
#   'estimated_dia_man_km': 0.331161605,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 42078.9385474708,
#   'astronomical_distance': 0.3919252468,
#   'miss_distance_km': 58631182.12050432,
#   'miss_distance_lunar': 152.4589210052,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1480999721},
#  {'id': 54425075,
#   'name': '(2024 BC8)',
#   'neo_reference_id': 54425075,
#   'absolute_magnitude_h': 25.4,
#   'estimated_dia_man_km': 0.0494356193,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 37783.590667016,
#   'astronomical_distance': 0.0159260612,
#   'miss_distance_km': 2382504.833009644,
#   'miss_distance_lunar': 6.1952378068,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.022108281},
#  {'id': 54425952,
#   'name': '(2024 CC2)',
#   'neo_reference_id': 54425952,
#   'absolute_magnitude_h': 24.28,
#   'estimated_dia_man_km': 0.0828018383,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 37065.4222106722,
#   'astronomical_distance': 0.169954958,
#   'miss_distance_km': 25424899.71273946,
#   'miss_distance_lunar': 66.112478662,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0370301078},
#  {'id': 54426072,
#   'name': '(2024 CH2)',
#   'neo_reference_id': 54426072,
#   'absolute_magnitude_h': 26.02,
#   'estimated_dia_man_km': 0.0371569432,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 34517.3912713385,
#   'astronomical_distance': 0.0145821987,
#   'miss_distance_km': 2181465.865436769,
#   'miss_distance_lunar': 5.6724752943,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0166170902},
#  {'id': 54427172,
#   'name': '(2024 CA8)',
#   'neo_reference_id': 54427172,
#   'absolute_magnitude_h': 24.32,
#   'estimated_dia_man_km': 0.0812905344,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 93884.4179856374,
#   'astronomical_distance': 0.0195001321,
#   'miss_distance_km': 2917178.226878627,
#   'miss_distance_lunar': 7.5855513869,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0363542322},
#  {'id': 54427945,
#   'name': '(2024 DY)',
#   'neo_reference_id': 54427945,
#   'absolute_magnitude_h': 29.02,
#   'estimated_dia_man_km': 0.0093334022,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 42539.5556571755,
#   'astronomical_distance': 0.0011472058,
#   'miss_distance_km': 171619.544131646,
#   'miss_distance_lunar': 0.4462630562,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0041740243},
#  {'id': 54429642,
#   'name': '(2024 EB1)',
#   'neo_reference_id': 54429642,
#   'absolute_magnitude_h': 22.84,
#   'estimated_dia_man_km': 0.1607089186,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 71247.7266769447,
#   'astronomical_distance': 0.1482833983,
#   'miss_distance_km': 22182880.542041622,
#   'miss_distance_lunar': 57.6822419387,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0718712133},
#  {'id': 54430151,
#   'name': '(2024 EU2)',
#   'neo_reference_id': 54430151,
#   'absolute_magnitude_h': 24.82,
#   'estimated_dia_man_km': 0.0645713667,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 45463.5957792013,
#   'astronomical_distance': 0.0333319329,
#   'miss_distance_km': 4986386.164822923,
#   'miss_distance_lunar': 12.9661218981,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0288771931},
#  {'id': 54430242,
#   'name': '(2024 EY2)',
#   'neo_reference_id': 54430242,
#   'absolute_magnitude_h': 22.01,
#   'estimated_dia_man_km': 0.2355266087,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-18',
#   'relative_velocity_kmph': 83986.1021090038,
#   'astronomical_distance': 0.072945355,
#   'miss_distance_km': 10912469.73439385,
#   'miss_distance_lunar': 28.375743095,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1053307015},
#  {'id': 2375657,
#   'name': '375657 (2009 CP5)',
#   'neo_reference_id': 2375657,
#   'absolute_magnitude_h': 21.49,
#   'estimated_dia_man_km': 0.2992540101,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 74283.9491011698,
#   'astronomical_distance': 0.3540964093,
#   'miss_distance_km': 52972068.60592819,
#   'miss_distance_lunar': 137.7435032177,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1338304618},
#  {'id': 3403150,
#   'name': '(2008 DC)',
#   'neo_reference_id': 3403150,
#   'absolute_magnitude_h': 20.1,
#   'estimated_dia_man_km': 0.5675968529,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 37934.1210678246,
#   'astronomical_distance': 0.4970225322,
#   'miss_distance_km': 74353512.15912642,
#   'miss_distance_lunar': 193.3417650258,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.2538370294},
#  {'id': 3627110,
#   'name': '(2013 DB1)',
#   'neo_reference_id': 3627110,
#   'absolute_magnitude_h': 26.07,
#   'estimated_dia_man_km': 0.0363111479,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 16559.8534677034,
#   'astronomical_distance': 0.088433617,
#   'miss_distance_km': 13229480.73959579,
#   'miss_distance_lunar': 34.400677013,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.016238839},
#  {'id': 3768616,
#   'name': '(2017 CO1)',
#   'neo_reference_id': 3768616,
#   'absolute_magnitude_h': 23.52,
#   'estimated_dia_man_km': 0.1175005715,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 83585.9932312525,
#   'astronomical_distance': 0.3884507432,
#   'miss_distance_km': 58111403.782636985,
#   'miss_distance_lunar': 151.1073391048,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.052547853},
#  {'id': 3799300,
#   'name': '(2018 CV2)',
#   'neo_reference_id': 3799300,
#   'absolute_magnitude_h': 25.56,
#   'estimated_dia_man_km': 0.0459240286,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 55729.2169098965,
#   'astronomical_distance': 0.38051136,
#   'miss_distance_km': 56923688.9668032,
#   'miss_distance_lunar': 148.01891904,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.02053785},
#  {'id': 3824086,
#   'name': '(2018 JH2)',
#   'neo_reference_id': 3824086,
#   'absolute_magnitude_h': 23.29,
#   'estimated_dia_man_km': 0.1306291133,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 57678.7181746838,
#   'astronomical_distance': 0.4468696653,
#   'miss_distance_km': 66850750.09649291,
#   'miss_distance_lunar': 173.8322998017,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0584191154},
#  {'id': 3838888,
#   'name': '(2019 EO)',
#   'neo_reference_id': 3838888,
#   'absolute_magnitude_h': 23.18,
#   'estimated_dia_man_km': 0.1374168468,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 39498.2505136019,
#   'astronomical_distance': 0.2702993505,
#   'miss_distance_km': 40436207.097183436,
#   'miss_distance_lunar': 105.1464473445,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0614546821},
#  {'id': 3989285,
#   'name': '(2020 BX12)',
#   'neo_reference_id': 3989285,
#   'absolute_magnitude_h': 20.63,
#   'estimated_dia_man_km': 0.4446721997,
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 78058.134299497,
#   'astronomical_distance': 0.3363588308,
#   'miss_distance_km': 50318564.6433704,
#   'miss_distance_lunar': 130.8435851812,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.1988634532},
#  {'id': 54099645,
#   'name': '(2020 XG4)',
#   'neo_reference_id': 54099645,
#   'absolute_magnitude_h': 23.01,
#   'estimated_dia_man_km': 0.1486072436,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 48051.7326021676,
#   'astronomical_distance': 0.3080289957,
#   'miss_distance_km': 46080481.65495916,
#   'miss_distance_lunar': 119.8232793273,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0664591797},
#  {'id': 54135431,
#   'name': '(2021 GV3)',
#   'neo_reference_id': 54135431,
#   'absolute_magnitude_h': 25.24,
#   'estimated_dia_man_km': 0.0532157244,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 27417.7483792997,
#   'astronomical_distance': 0.28862599,
#   'miss_distance_km': 43177833.3306413,
#   'miss_distance_lunar': 112.27551011,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0237987955},
#  {'id': 54143420,
#   'name': '(2021 JE1)',
#   'neo_reference_id': 54143420,
#   'absolute_magnitude_h': 26.68,
#   'estimated_dia_man_km': 0.0274182656,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 26841.5639251402,
#   'astronomical_distance': 0.2965292368,
#   'miss_distance_km': 44360142.21800561,
#   'miss_distance_lunar': 115.3498731152,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0122618211},
#  {'id': 54248944,
#   'name': '(2022 DX4)',
#   'neo_reference_id': 54248944,
#   'absolute_magnitude_h': 24.8,
#   'estimated_dia_man_km': 0.0651688382,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 18484.9173411146,
#   'astronomical_distance': 0.2017248677,
#   'miss_distance_km': 30177610.5339518,
#   'miss_distance_lunar': 78.4709735353,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0291443905},
#  {'id': 54293659,
#   'name': '(2022 PW)',
#   'neo_reference_id': 54293659,
#   'absolute_magnitude_h': 25.37,
#   'estimated_dia_man_km': 0.0501233372,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 65975.6395235668,
#   'astronomical_distance': 0.3668317229,
#   'miss_distance_km': 54877244.39427023,
#   'miss_distance_lunar': 142.6975402081,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0224158379},
#  {'id': 54330724,
#   'name': '(2022 WA10)',
#   'neo_reference_id': 54330724,
#   'absolute_magnitude_h': 26.45,
#   'estimated_dia_man_km': 0.0304817558,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 75680.9728027348,
#   'astronomical_distance': 0.2813233572,
#   'miss_distance_km': 42085375.01836916,
#   'miss_distance_lunar': 109.4347859508,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0136318556},
#  {'id': 54340429,
#   'name': '(2023 BT7)',
#   'neo_reference_id': 54340429,
#   'absolute_magnitude_h': 23.58,
#   'estimated_dia_man_km': 0.1142983547,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 36017.068868496,
#   'astronomical_distance': 0.3708380373,
#   'miss_distance_km': 55476580.49506055,
#   'miss_distance_lunar': 144.2559965097,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0511157782},
#  {'id': 54341525,
#   'name': '(2023 CA2)',
#   'neo_reference_id': 54341525,
#   'absolute_magnitude_h': 24.1,
#   'estimated_dia_man_km': 0.0899580388,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 66049.1734075063,
#   'astronomical_distance': 0.1945740959,
#   'miss_distance_km': 29107870.303815734,
#   'miss_distance_lunar': 75.6893233051,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.040230458},
#  {'id': 54422949,
#   'name': '(2024 BB3)',
#   'neo_reference_id': 54422949,
#   'absolute_magnitude_h': 20.55,
#   'estimated_dia_man_km': 0.4613600429,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 80823.8812126122,
#   'astronomical_distance': 0.3586222649,
#   'miss_distance_km': 53649126.96361576,
#   'miss_distance_lunar': 139.5040610461,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.2063264836},
#  {'id': 54423326,
#   'name': '(2024 BJ5)',
#   'neo_reference_id': 54423326,
#   'absolute_magnitude_h': 22.52,
#   'estimated_dia_man_km': 0.1862258558,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 42991.5232459825,
#   'astronomical_distance': 0.0953339401,
#   'miss_distance_km': 14261754.377667587,
#   'miss_distance_lunar': 37.0849026989,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0832827346},
#  {'id': 54426233,
#   'name': '(2024 CZ2)',
#   'neo_reference_id': 54426233,
#   'absolute_magnitude_h': 25.93,
#   'estimated_dia_man_km': 0.0387293295,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': '2024-02-17',
#   'relative_velocity_kmph': 20164.6635636747,
#   'astronomical_distance': 0.0902234806,
#   'miss_distance_km': 13497240.521746323,
#   'miss_distance_lunar': 35.0969339534,
#   'orbiting_body': 'Earth',
#   'estimated_dia_min': 0.0173202827},
#  ...]

# %%
import sqlite3

# %%
conn = sqlite3.connect('mydb.db')
cursor = conn.cursor()

# %%
cursor.execute('''CREATE TABLE asteroids (
                    id INTEGER,
                    name varchar2(100),
                    absolute_magnitude_h float,
                    estimated_diameter_min_km float,
                    estimated_diameter_max_km float,
                    is_potentially_hazardous_asteroid boolean
                )''')

# %%
cursor.execute('select * from asteroids')

# %%
import pandas as pd

 # sample dataframe

data = asteroids
df = pd.DataFrame(data)
df
# Out:
#             id                name  neo_reference_id  absolute_magnitude_h  \
# 0      2415949  415949 (2001 XY10)           2415949                 19.37
# 1      3160747         (2003 SR84)           3160747                 26.00
# 2      3309828         (2005 YQ96)           3309828                 20.62
# 3      3457842         (2009 HC21)           3457842                 22.10
# 4      3553062         (2010 XA11)           3553062                 26.10
# ...        ...                 ...               ...                   ...
# 9995  54527148           (2025 HM)          54527148                 22.62
# 9996  54527277           (2025 HX)          54527277                 27.55
# 9997  54527285          (2025 HF1)          54527285                 26.27
# 9998  54527601          (2025 HS3)          54527601                 23.87
# 9999  54528050         (2025 HO12)          54528050                 28.32
#
#       estimated_dia_man_km  is_potentially_hazardous_asteroid  \
# 0                 0.794401                              False
# 1                 0.037501                              False
# 2                 0.446725                               True
# 3                 0.225964                              False
# 4                 0.035813                              False
# ...                    ...                                ...
# 9995              0.177844                              False
# 9996              0.018367                              False
# 9997              0.033116                              False
# 9998              0.100009                              False
# 9999              0.012884                              False
#
#      close_approach_date  relative_velocity_kmph  astronomical_distance  \
# 0             2024-01-02            57205.895120               0.337254
# 1             2024-01-02            38589.054833               0.132343
# 2             2024-01-02            56413.014352               0.167013
# 3             2024-01-02            21891.118219               0.492051
# 4             2024-01-02            31468.978359               0.235802
# ...                  ...                     ...                    ...
# 9995          2025-04-24            41818.829521               0.038757
# 9996          2025-04-24            45498.124303               0.009082
# 9997          2025-04-24            53094.805588               0.002634
# 9998          2025-04-24            43402.802771               0.179860
# 9999          2025-04-24            39331.952580               0.010536
#
#       miss_distance_km  miss_distance_lunar orbiting_body  estimated_dia_min
# 0         5.045241e+07           131.191622         Earth           0.355267
# 1         1.979817e+07            51.481268         Earth           0.016771
# 2         2.498473e+07            64.967910         Earth           0.199781
# 3         7.360980e+07           191.407879         Earth           0.101054
# 4         3.527551e+07            91.727075         Earth           0.016016
# ...                ...                  ...           ...                ...
# 9995      5.798018e+06            15.076612         Earth           0.079534
# 9996      1.358625e+06             3.532839         Earth           0.008214
# 9997      3.940261e+05             1.024588         Earth           0.014810
# 9998      2.690670e+07            69.965606         Earth           0.044725
# 9999      1.576126e+06             4.098407         Earth           0.005762
#
# [10000 rows x 13 columns]

# %%
insert = "insert into asteroids values(?,?,?,?,?,?)"

for i in asteroids:
 values = (i["id"],i['name'],
           i['absolute_magnitude_h'],
           i['estimated_dia_man_km'],
           i['estimated_dia_min'],
           i['is_potentially_hazardous_asteroid'])
 cursor.execute(insert,values)
conn.commit()

# %%
cursor.execute("SELECT * FROM asteroids")

rows = cursor.fetchall()

for i in rows:
    print(i)

# %%
cursor.execute('''CREATE TABLE close_approach (
                    neo_reference_id INTEGER,
                    close_approach_date date,
                    relative_velocity_kmph float,
                    astronomical float,
                    miss_distance_km float,
                    miss_distance_lunar float,
                    orbiting_body varchar2(100)
                )''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipython-input-1754604618.py in <cell line: 0>()
# ----> 1 cursor.execute('''CREATE TABLE close_approach (
#       2                     neo_reference_id INTEGER,
#       3                     close_approach_date date,
#       4                     relative_velocity_kmph float,
#       5                     astronomical float,
#
# OperationalError: table close_approach already exists

# %%
insert1 = "insert into close_approach values(?,?,?,?,?,?,?)"

for j in asteroids:
 values1 = (j["neo_reference_id"],j['close_approach_date'],
           j['relative_velocity_kmph'],
           j['astronomical_distance'],
           j['miss_distance_km'],
           j['miss_distance_lunar'],
           j['orbiting_body'])
 cursor.execute(insert1,values1)
conn.commit()

# %%
#cursor.execute("SELECT * FROM close_approach")
cursor.execute("SELECT * FROM asteroids")
rec = cursor.fetchall()

for j in rec:
    print(j)
# Out:
# (2415949, '415949 (2001 XY10)', 19.37, 0.7944013596, 0.3552670883, 0)
# (3160747, '(2003 SR84)', 26.0, 0.0375007522, 0.0167708462, 0)
# (3309828, '(2005 YQ96)', 20.62, 0.4467247133, 0.1997813652, 1)
# (3457842, '(2009 HC21)', 22.1, 0.2259643771, 0.1010543415, 0)
# (3553062, '(2010 XA11)', 26.1, 0.0358129403, 0.0160160338, 0)
# (3591616, '(2011 YP10)', 23.94, 0.0968366995, 0.0433066885, 0)
# (3608936, '(2012 SD22)', 20.05, 0.580817882, 0.2597496533, 1)
# (3795154, '(2017 YD8)', 21.87, 0.2512117673, 0.1123453177, 0)
# (3842680, '(2019 KK5)', 22.79, 0.1644523102, 0.0735453089, 0)
# (2613286, '613286 (2005 YQ96)', 20.63, 0.4446721997, 0.1988634532, 1)
# (54338714, '(2023 AW)', 25.68, 0.0434550225, 0.0194336768, 0)
# (54415081, '(2023 XZ4)', 24.05, 0.0920534307, 0.0411675457, 0)
# (54417653, '(2023 YR)', 24.9, 0.0622357573, 0.0278326768, 0)
# (54418497, '(2024 AA)', 27.41, 0.01959025, 0.0087610261, 0)
# (54418796, '(2022 OY78)', 26.38, 0.0314803809, 0.0140784543, 0)
# (54419485, '(2024 AQ1)', 23.72, 0.1071617948, 0.0479242116, 0)
# (54419601, '(2024 AA2)', 20.54, 0.4634895841, 0.2072788434, 0)
# (54420153, '(2024 AR3)', 23.6, 0.1132504611, 0.0506471459, 0)
# (54421393, '(2024 BK1)', 24.49, 0.0751692087, 0.0336166921, 0)
# (2669051, '669051 (2012 SD22)', 20.08, 0.5728487619, 0.2561857545, 1)
# (54444997, '(2024 KY)', 26.5, 0.0297879063, 0.0133215567, 0)
# (54445206, '(2024 KJ1)', 26.21, 0.0340439527, 0.0152249185, 0)
# (3724393, '(2015 OD22)', 21.21, 0.3404395273, 0.152249185, 0)
# (3797695, '(2018 BA)', 25.0, 0.0594346868, 0.02658, 0)
# (3986699, '(2020 BC)', 26.2, 0.0342010925, 0.0152951935, 0)
# (54200446, '(2021 SG2)', 25.54, 0.0463489584, 0.0207278843, 0)
# (54235663, '(2022 AO2)', 24.19, 0.0863057993, 0.0385971268, 0)
# (54418438, '(2023 YR1)', 25.68, 0.0434550225, 0.0194336768, 0)
# (54418650, '(2023 YY1)', 25.77, 0.041690776, 0.0186446818, 0)
# (54419698, '(2024 AV2)', 26.64, 0.0279280092, 0.0124897854, 0)
# (54421384, '(2024 AA6)', 25.12, 0.0562393094, 0.0251509837, 0)
# (54513047, '(2025 AB)', 27.13, 0.022286403, 0.0099667824, 0)
# (2450293, '450293 (2004 LV3)', 18.83, 1.0186851583, 0.4555698523, 1)
# (3541505, '(2010 PJ)', 22.14, 0.2218400624, 0.0992098919, 0)
# (3759758, '(2016 SU2)', 27.6, 0.0179489885, 0.0080270317, 0)
', 25.2, 0.0542050786, 0.0242412481, 0)
# (54518077, '(2025 CD)', 28.45, 0.0121350055, 0.0054269395, 0)
# (54526031, '(2025 FJ22)', 25.65, 0.044059542, 0.0197040262, 0)
# (3023012, '(1999 RA32)', 21.39, 0.3133574171, 0.1401376972, 0)
# (3445538, '(2009 BE81)', 21.21, 0.3404395273, 0.152249185, 1)
# (3710919, '(2015 DP53)', 24.4, 0.0783501764, 0.0350392641, 0)
# (3757410, '(2016 PA40)', 24.49, 0.0751692087, 0.0336166921, 0)
# (3782020, '(2017 TA)', 24.8, 0.0651688382, 0.0291443905, 0)
# ...
# (3892698, '(2019 VP3)', 28.1, 0.0142573883, 0.0063760979, 0)
# (54134541, '(2021 GN)', 23.45, 0.1213500554, 0.0542693946, 0)
# (54433733, '(2024 GU3)', 25.79, 0.0413085527, 0.0184737464, 0)
# (54525114, '(2025 FY13)', 24.9, 0.0622357573, 0.0278326768, 0)
# (54527072, '(2025 GP1)', 26.02, 0.0371569432, 0.0166170902, 0)
# (3152317, '(2003 GQ22)', 21.34, 0.320656449, 0.1434019235, 1)
# (3551067, '(2010 VD72)', 21.54, 0.2924421572, 0.1307841086, 1)
# (3728860, '(2015 SC17)', 22.95, 0.1527706684, 0.0683211199, 0)
# (3744157, '(2016 CP247)', 23.6, 0.1132504611, 0.0506471459, 0)
# (54053823, '(2020 RF2)', 25.5, 0.0472106499, 0.0211132445, 0)
# (54132973, '(2021 FE3)', 24.16, 0.0875064325, 0.0391340663, 0)
# (54226400, '(2021 XA1)', 26.98, 0.023880311, 0.0106795998, 0)
# (54524517, '(2025 FZ5)', 22.83, 0.1614507173, 0.0722029558, 0)
# (54524973, '(2025 FS10)', 24.87, 0.063101543, 0.0282198679, 0)
# (54525375, '(2025 FF15)', 23.24, 0.1336718562, 0.0597798714, 0)
# (54525866, '(2025 FF22)', 24.55, 0.0731206391, 0.0327005439, 0)
# (54526423, '(2025 GW)', 27.09, 0.0227007381, 0.0101520787, 0)
# (54526555, '(2025 GC1)', 23.09, 0.1432319745, 0.0640552863, 0)
# (54527391, '(2025 HD2)', 23.92, 0.0977327184, 0.0437074004, 0)
# (54527892, '(2025 HP6)', 20.69, 0.4325536477, 0.193443872, 0)
# (2085953, '85953 (1999 FK21)', 18.09, 1.4323197447, 0.6405528629, 0)
# (3278402, '(2005 KA)', 24.7, 0.0682401509, 0.0305179233, 0)
# (3516633, '(2010 HA)', 23.9, 0.0986370281, 0.04411182, 0)
# (3747992, '(2016 FY2)', 25.5, 0.0472106499, 0.0211132445, 0)
# (54054283, '(2020 RB6)', 25.3, 0.0517654482, 0.0231502122, 0)
# (54225505, '(2021 GA168)', 28.86, 0.0100470827, 0.004493192, 0)
# (54310122, '(2022 SY24)', 28.98, 0.0095069231, 0.0042516252, 0)
# (54521719, '(2025 DL28)', 24.67, 0.069189466, 0.0309424699, 0)
# (54525365, '(2025 FN14)', 24.86, 0.0633928065, 0.0283501249, 0)
# (54525638, '(2025 FF18)', 25.84, 0.0403682552, 0.0180532326, 0)
# (54526264, '(2025 GT)', 26.83, 0.0255882143, 0.0114433973, 0)
# (54526716, '(2025 GK1)', 24.92, 0.0616651765, 0.0275775053, 0)
# (54527080, '(2025 GR1)', 25.54, 0.0463489584, 0.0207278843, 0)
# (54527085, '(2025 HA)', 23.05, 0.1458948557, 0.065246163, 0)
# (54527592, '(2025 HJ3)', 26.22, 0.033887535, 0.0151549664, 0)
# (54527602, '(2025 HV3)', 24.85, 0.0636854144, 0.0284809831, 0)
# (3407680, '(2008 FW6)', 21.0, 0.3750075218, 0.1677084622, 1)
# (3692749, '(2014 TL17)', 22.91, 0.1556108872, 0.0695913044, 0)
# (3780633, '(2017 PK25)', 25.3, 0.0517654482, 0.0231502122, 0)
# (54293660, '(2022 PX)', 24.29, 0.0824213984, 0.0368599699, 0)
# (54304629, '(2022 SW)', 25.14, 0.0557237043, 0.0249203981, 0)
# (54397460, '(2023 UY3)', 26.87, 0.0251211767, 0.0112345318, 0)
# (54484277, '(2024 SM4)', 24.04, 0.0924783301, 0.0413575665, 0)
# (54496629, '(2024 UZ9)', 24.47, 0.0758647409, 0.0339277435, 0)
# (54525110, '(2025 FW12)', 22.82, 0.1621959399, 0.0725362295, 0)
# (54526424, '(2025 GX)', 26.83, 0.0255882143, 0.0114433973, 0)
# (54526427, '(2025 GA1)', 26.76, 0.0264265201, 0.0118182991, 0)
# (54527383, '(2025 HX1)', 24.54, 0.0734581487, 0.0328514828, 0)
# (2436030, '436030 (2009 JO2)', 19.43, 0.7727517171, 0.3455850738, 0)
# (3137735, '(2002 TX59)', 23.9, 0.0986370281, 0.04411182, 0)
# (3153509, '(2003 HM)', 22.11, 0.2249261651, 0.100590039, 0)
# (3830886, '(2018 SN2)', 24.4, 0.0783501764, 0.0350392641, 0)
# (3841545, '(2019 HS2)', 26.6, 0.0284472297, 0.0127219879, 0)
# (54100193, '(2020 XD5)', 19.81, 0.648694146, 0.2901048414, 1)
# (54102026, '(2020 YW3)', 25.73, 0.0424658654, 0.0189913123, 0)
# (54104267, '(2021 AR)', 23.95, 0.0963917753, 0.0431077124, 0)
# (54248953, '(2022 ET)', 30.22, 0.0053708123, 0.0024019003, 0)
# (54524978, '(2025 FV11)', 23.75, 0.1056914799, 0.0472666667, 0)
# (54524983, '(2025 FK12)', 26.02, 0.0371569432, 0.0166170902, 0)
# (54527116, '(2025 HC)', 26.42, 0.0309057992, 0.0138214936, 0)
# (54527120, '(2025 HE)', 27.38, 0.0198627775, 0.0088829042, 0)
# (54527147, '(2025 HK)', 25.88, 0.0396314515, 0.0177237239, 0)
# (54527279, '(2025 HZ)', 29.12, 0.0089133299, 0.0039861623, 0)
# (54527280, '(2025 HA1)', 25.71, 0.0428587972, 0.0191670368, 0)
# (54527594, '(2025 HM3)', 26.68, 0.0274182656, 0.0122618211, 0)
# (54528051, '(2025 HW12)', 25.48, 0.0476474846, 0.0213086029, 0)
# (2009058, '9058 (1992 JB)', 17.81, 1.6294460236, 0.7287104149, 0)
# (3418110, '(2008 NP3)', 22.83, 0.1614507173, 0.0722029558, 0)
# (3599541, '(2012 DO8)', 22.34, 0.2023205415, 0.0904804968, 0)
# (3879726, '(2019 UU6)', 23.6, 0.1132504611, 0.0506471459, 0)
# (54016548, '(2020 HJ)', 25.3, 0.0517654482, 0.0231502122, 0)
# (54017086, '(2020 KT)', 24.05, 0.0920534307, 0.0411675457, 0)
# (54051303, '(2020 QN3)', 21.02, 0.3715694322, 0.1661709017, 0)
# (54102028, '(2020 YY3)', 26.47, 0.0302022973, 0.013506878, 0)
# (54143218, '(2021 JQ)', 23.8, 0.1032856481, 0.046190746, 0)
# (54432465, '(2024 GR)', 27.75, 0.0167509707, 0.0074912618, 0)
# (54490515, '(2024 TL10)', 24.71, 0.0679266159, 0.0303777061, 0)
# (54356032, '(2023 HU3)', 25.01, 0.0591616093, 0.026457876, 0)
# (54504537, '(2024 XY5)', 25.99, 0.0376738478, 0.0168482569, 0)
# (54519236, '(2025 CQ2)', 22.69, 0.1722027088, 0.0770113926, 0)
# (54520805, '(2025 DJ7)', 23.82, 0.1023387195, 0.0457672667, 0)
# (54524509, '(2025 FT5)', 25.32, 0.0512908597, 0.0229379698, 0)
# (54526717, '(2025 GL1)', 23.44, 0.1219101818, 0.0545198907, 0)
# (54527154, '(2025 HR)', 26.37, 0.0316256878, 0.0141434375, 0)
# (54527375, '(2025 HQ1)', 25.77, 0.041690776, 0.0186446818, 0)
# (54527598, '(2025 HQ3)', 26.79, 0.0260639347, 0.0116561459, 0)
# (54527660, '(2025 HA5)', 26.52, 0.0295148091, 0.0131994239, 0)
# (3516408, '(2010 GK65)', 24.5, 0.0748238376, 0.0334622374, 0)
# (3717054, '(2015 HW10)', 25.7, 0.0430566244, 0.0192555078, 0)
# (54219290, '(2021 VW10)', 23.39, 0.1247498347, 0.0557898221, 0)
# (54305658, '(2022 SR4)', 25.69, 0.0432553648, 0.0193443872, 0)
# (54354402, '(2023 GH2)', 23.7, 0.1081533507, 0.0483676488, 0)
# (54393421, '(2023 TK12)', 25.77, 0.041690776, 0.0186446818, 0)
# (54434765, '(2024 HB)', 27.99, 0.0149982289, 0.0067074119, 0)
# (54494719, '(2024 UJ1)', 26.75, 0.0265484994, 0.0118728499, 0)
# (54525459, '(2025 FA16)', 23.73, 0.1066694311, 0.0477040198, 0)
# (54526042, '(2025 FY22)', 25.22, 0.0537081235, 0.024019003, 0)
# (54527117, '(2025 HB)', 27.72, 0.0169839999, 0.0075954757, 0)
# (54527122, '(2025 HG)', 26.62, 0.0281864239, 0.012605352, 0)
# (54527151, '(2025 HO)', 29.33, 0.0080917038, 0.00361872, 0)
# (54527281, '(2025 HB1)', 24.24, 0.0843412394, 0.0377185489, 0)
# (54527739, '(2025 HP5)', 23.88, 0.0995497053, 0.0445199816, 0)
# (2009058, '9058 (1992 JB)', 17.81, 1.6294460236, 0.7287104149, 0)
# (3418110, '(2008 NP3)', 22.83, 0.1614507173, 0.0722029558, 0)
# (3599541, '(2012 DO8)', 22.34, 0.2023205415, 0.0904804968, 0)
# (3879726, '(2019 UU6)', 23.6, 0.1132504611, 0.0506471459, 0)
# (54016548, '(2020 HJ)', 25.3, 0.0517654482, 0.0231502122, 0)
# (54017086, '(2020 KT)', 24.05, 0.0920534307, 0.0411675457, 0)
# (54051303, '(2020 QN3)', 21.02, 0.3715694322, 0.1661709017, 0)
# (54102028, '(2020 YY3)', 26.47, 0.0302022973, 0.013506878, 0)
# (54143218, '(2021 JQ)', 23.8, 0.1032856481, 0.046190746, 0)
# (54432465, '(2024 GR)', 27.75, 0.0167509707, 0.0074912618, 0)
# (54490515, '(2024 TL10)', 24.71, 0.0679266159, 0.0303777061, 0)
# (54502877, '(2024 UY43)', 25.16, 0.0552128263, 0.0246919266, 0)
# (54521727, '(2025 DY29)', 25.28, 0.052244428, 0.0233644185, 0)
# (54525464, '(2025 FS16)', 24.34, 0.0805452583, 0.0360209346, 0)
# (54527123, '(2025 HF)', 25.64, 0.0442629117, 0.0197949759, 0)
# (54527150, '(2025 HN)', 26.83, 0.0255882143, 0.0114433973, 0)
# (54527286, '(2025 HH1)', 25.21, 0.0539560289, 0.0241298697, 0)
# (54527389, '(2025 HE2)', 24.83, 0.0642746882, 0.0287445144, 0)
# (54527604, '(2025 HX3)', 27.38, 0.0198627775, 0.0088829042, 0)
# (54527650, '(2025 HO4)', 24.72, 0.0676145215, 0.0302381333, 0)
# (3126185, '(2002 JQ100)', 19.8, 0.6516883822, 0.2914439045, 0)
# (3557843, '(2011 DV)', 20.79, 0.4130855266, 0.1847374636, 1)
# (3634388, '(2013 GR38)', 21.96, 0.2410127282, 0.1077841687, 1)
# (3636252, '(2013 HJ19)', 21.5, 0.2978790628, 0.1332155667, 0)
# (3702717, '(2014 YE1)', 23.4, 0.1241766613, 0.0555334912, 0)
# (3840753, '(2019 FY2)', 27.4, 0.0196806745, 0.0088014652, 0)
# (3873162, '(2019 SW9)', 24.5, 0.0748238376, 0.0334622374, 0)
# (54016713, '(2020 HX4)', 26.3, 0.0326617897, 0.0146067964, 0)
# (54017652, '(2020 MK3)', 25.8, 0.0411187571, 0.0183888672, 0)
# (54134556, '(2021 GC1)', 28.25, 0.013305769, 0.0059505208, 0)
# (54282890, '(2022 LA3)', 26.0, 0.0375007522, 0.0167708462, 0)
# (54338709, '(2023 AR)', 25.02, 0.0588897864, 0.0263363131, 0)
# (54372216, '(2023 LO)', 27.57, 0.0181986838, 0.0081386988, 0)
# (54397132, '(2023 UP2)', 26.69, 0.0272922901, 0.0122054832, 0)
# (54435949, '(2024 HZ)', 28.69, 0.0108652564, 0.0048590904, 0)
# (54502168, '(2024 WC15)', 20.9, 0.3926810818, 0.1756123185, 1)
# (54527148, '(2025 HM)', 22.62, 0.1778443116, 0.079534394, 0)
# (54527277, '(2025 HX)', 27.55, 0.0183670741, 0.0082140053, 0)
# (54527285, '(2025 HF1)', 26.27, 0.0331161605, 0.0148099972, 0)
# (54527601, '(2025 HS3)', 23.87, 0.1000092059, 0.0447254765, 0)
# (54528050, '(2025 HO12)', 28.32, 0.0128836815, 0.0057617575, 0)

# %% [markdown]
# 1.Count how many times each asteroid has approached Earth

# %%
cursor.execute('''SELECT name,count(orbiting_body) FROM asteroids ,close_approach
where id=neo_reference_id
and orbiting_body="Earth"
group by id''')
rec = cursor.fetchall()

for j in rec:
    print(j)

# %% [markdown]
# 2.Average velocity of each asteroid over multiple approaches

# %%
import pandas as pd
cursor.execute('''SELECT name,avg(distinct relative_velocity_kmph) FROM asteroids ,close_approach
where id=neo_reference_id
group by id''')
rec = cursor.fetchall()

#for j in rec:
  #  print(j)

data = rec
df = pd.DataFrame(data)
df
# Out:
#                            0             1
# 0       887 Alinda (A918 AA)  29695.316012
# 1        1685 Toro (1948 OA)  58226.721106
# 2     2063 Bacchus (1977 HB)  30698.842978
# 3      2340 Hathor (1976 UA)  93669.384688
# 4      4034 Vishnu (1986 PA)  43128.810103
# ...                      ...           ...
# 7500              (2025 QV5)  14442.309278
# 7501              (2025 QP8)  29277.388783
# 7502              (2025 QM9)  40244.628606
# 7503              (2025 PN7)   6847.455385
# 7504               (2025 RB)  61098.852889
#
# [7505 rows x 2 columns]

# %% [markdown]
# 3.List top 10 fastest asteroids

# %%
import pandas as pd
cursor.execute('''select * from (SELECT name,relative_velocity_kmph,dense_rank()over(order by relative_velocity_kmph desc) rk FROM asteroids ,close_approach
where id=neo_reference_id)where rk<=10''')
rec = cursor.fetchall()

#for j in rec:
  #  print(j)

data = rec
df = pd.DataFrame(data)
df
# Out:
#              0              1   2
# 0   (2022 HB4)  190513.420686   1
# 1   (2023 TS3)  173071.830081   2
# 2   (2018 GG5)  161520.897925   3
# 3  (2017 WP28)  158279.864701   4
# 4    (2008 QB)  154336.407297   5
# 5   (1999 GR6)  152218.220518   6
# 6  (2011 WD39)  151520.395439   7
# 7    (2024 MH)  150599.454097   8
# 8   (2021 CQ3)  150583.019419   9
# 9   (2007 RT1)  149261.278634  10

# %% [markdown]
# 4.Find potentially hazardous asteroids that have approached Earth more than 3 times

# %%
import pandas
cursor.execute('''SELECT name,count(is_potentially_hazardous_asteroid) FROM asteroids ,close_approach
where id=neo_reference_id
and orbiting_body="Earth"
and is_potentially_hazardous_asteroid=1
group by id
having count(is_potentially_hazardous_asteroid)>3''')
rec = cursor.fetchall()

dataset=rec
ds=pd.DataFrame(dataset)
ds
# Out:
#                            0  1
# 0          26663 (2000 XK47)  4
# 1   101955 Bennu (1999 RQ36)  4
# 2          162361 (2000 AF6)  4
# 3         162421 (2000 ET70)  4
# 4         163026 (2001 XR30)  4
# ..                       ... ..
# 83                 (2024 OY)  4
# 84                (2024 TN1)  4
# 85               (2024 TS20)  4
# 86                (2025 AK2)  9
# 87                (2025 BT1)  4
#
# [88 rows x 2 columns]

# %% [markdown]
# 5.Find the month with the most asteroid approaches

# %%
import pandas
cursor.execute('''select * from (SELECT count(DISTINCT name) cnt,close_approach_date FROM asteroids ,close_approach
where id=neo_reference_id
group by close_approach_date)
order by cnt desc
limit 1''')
rec = cursor.fetchall()

dataset=rec
ds=pd.DataFrame(dataset)
ds
# Out:
#     0           1
# 0  39  2024-10-05

# %% [markdown]
# 6.Get the asteroid with the fastest ever approach speed

# %%
import pandas
cursor.execute('''SELECT name,max(relative_velocity_kmph) FROM asteroids ,close_approach
where id=neo_reference_id''')
rec = cursor.fetchall()

dataset=rec
ds=pd.DataFrame(dataset)
ds
# Out:
#             0              1
# 0  (2022 HB4)  190513.420686

# %% [markdown]
# 7.Sort asteroids by maximum estimated diameter (descending)

# %%
import pandas
cursor.execute('''SELECT a.* FROM asteroids a ,close_approach
where id=neo_reference_id
order by estimated_diameter_min_km desc''')
rec = cursor.fetchall()

dataset=rec
ds=pd.DataFrame(dataset)
ds
# Out:
#               0                     1      2          3         4  5
# 0       2000887  887 Alinda (A918 AA)  13.81  10.281109  4.597852  0
# 1       2001685   1685 Toro (1948 OA)  14.28   8.280184  3.703011  0
# 2       2066146      66146 (1998 TU3)  14.36   7.980681  3.569069  0
# 3       2005660        5660 (1974 MA)  15.38   4.989304  2.231285  0
# 4       2533671    533671 (2014 LJ21)  15.90   3.926811  1.756123  1
# ...         ...                   ...    ...        ...       ... ..
# 16003  54380194             (2023 RS)  32.32   0.002042  0.000913  0
# 16004  54380194             (2023 RS)  32.32   0.002042  0.000913  0
# 16005  54380194             (2023 RS)  32.32   0.002042  0.000913  0
# 16006  54473959           (2024 RC42)  32.38   0.001986  0.000888  0
# 16007  54496614            (2024 UG9)  32.61   0.001787  0.000799  0
#
# [16008 rows x 6 columns]

# %% [markdown]
# 9.Display the name of each asteroid along with the date and miss distance of its closest approach to Earth.

# %%
import pandas
cursor.execute('''SELECT name,close_approach_date,miss_distance_km FROM asteroids ,close_approach
where id=neo_reference_id
and orbiting_body="Earth"''')
rec = cursor.fetchall()

dataset=rec
ds=pd.DataFrame(dataset)
ds
# Out:
#                         0           1             2
# 0      415949 (2001 XY10)  2024-01-02  5.045241e+07
# 1      415949 (2001 XY10)  2024-01-02  5.045241e+07
# 2             (2003 SR84)  2024-01-02  1.979817e+07
# 3             (2005 YQ96)  2024-01-02  2.498473e+07
# 4             (2009 HC21)  2024-01-02  7.360980e+07
# ...                   ...         ...           ...
# 16003           (2025 HM)  2025-04-24  5.798018e+06
# 16004           (2025 HX)  2025-04-24  1.358625e+06
# 16005          (2025 HF1)  2025-04-24  3.940261e+05
# 16006          (2025 HS3)  2025-04-24  2.690670e+07
# 16007         (2025 HO12)  2025-04-24  1.576126e+06
#
# [16008 rows x 3 columns]

# %% [markdown]
# 10.List names of asteroids that approached Earth with velocity > 50,000 km/h

# %%
import pandas
cursor.execute('''SELECT name,relative_velocity_kmph FROM asteroids ,close_approach
where id=neo_reference_id
and orbiting_body="Earth"
and relative_velocity_kmph>50000''')
rec = cursor.fetchall()

dataset=rec
ds=pd.DataFrame(dataset)
ds
# Out:
#                        0              1
# 0     415949 (2001 XY10)   57205.895120
# 1     415949 (2001 XY10)   57205.895120
# 2            (2005 YQ96)   56413.014352
# 3             (2017 YD8)   68377.113479
# 4             (2019 KK5)   74999.269000
# ...                  ...            ...
# 5412           (2023 AR)  132519.600147
# 5413           (2023 LO)   55509.160201
# 5414          (2023 UP2)   52792.998884
# 5415          (2023 UP2)   52792.998884
# 5416          (2025 HF1)   53094.805588
#
# [5417 rows x 2 columns]

# %% [markdown]
# 11.Count how many approaches happened per month

# %%
import pandas
cursor.execute('''SELECT count(DISTINCT name),strftime('%m',close_approach_date) FROM asteroids ,close_approach
where id=neo_reference_id
group by strftime('%m',close_approach_date)''')
rec = cursor.fetchall()

dataset=rec
ds=pd.DataFrame(dataset)
ds
# Out:
#        0   1
# 0   1017  01
# 1    998  02
# 2   1048  03
# 3    966  04
# 4    494  05
# 5    445  06
# 6    417  07
# 7    531  08
# 8    709  09
# 9    784  10
# 10   592  11
# 11   593  12

# %% [markdown]
# 12.Find asteroid with the highest brightness (lowest magnitude value)

# %%
import pandas
cursor.execute('''SELECT name,min(absolute_magnitude_h) FROM asteroids ,close_approach
where id=neo_reference_id''')
rec = cursor.fetchall()

dataset=rec
ds=pd.DataFrame(dataset)
ds
# Out:
#                       0      1
# 0  887 Alinda (A918 AA)  13.81

# %% [markdown]
# 13.Get number of hazardous vs non-hazardous asteroids

# %%
import pandas
cursor.execute('''SELECT count(DISTINCT name),"Non-hazardous asteroids" FROM asteroids ,close_approach
where id=neo_reference_id
and is_potentially_hazardous_asteroid=0
union
SELECT count( DISTINCT name),"Hazardous asteroids" FROM asteroids ,close_approach
where id=neo_reference_id
and is_potentially_hazardous_asteroid=1''')
rec = cursor.fetchall()

dataset=rec
ds=pd.DataFrame(dataset)
ds
# Out:
#       0                        1
# 0   388      Hazardous asteroids
# 1  7117  Non-hazardous asteroids

# %% [markdown]
# 14.Find asteroids that passed closer than the Moon (lesser than 1 LD), along with their close approach date and distance.

# %%
import pandas
cursor.execute('''SELECT name,close_approach_date,miss_distance_lunar FROM asteroids ,close_approach
where id=neo_reference_id
and miss_distance_lunar<1''')
rec = cursor.fetchall()

dataset=rec
ds=pd.DataFrame(dataset)
ds
# Out:
#                0           1         2
# 0      (2024 AD)  2024-01-04  0.631031
# 1    (2024 BA16)  2024-01-15  0.364068
# 2    (2024 BA16)  2024-01-15  0.364068
# 3     (2024 AZ3)  2024-01-14  0.647173
# 4     (2024 AG4)  2024-01-11  0.885273
# ..           ...         ...       ...
# 349   (2025 HA1)  2025-04-20  0.302414
# 350   (2025 GS1)  2025-04-15  0.098785
# 351    (2025 HH)  2025-04-17  0.072433
# 352    (2025 HH)  2025-04-17  0.072433
# 353    (2025 HO)  2025-04-19  0.486516
#
# [354 rows x 3 columns]

# %% [markdown]
# 15.Find asteroids that came within 0.05 AU(astronomical distance)

# %%
import pandas
cursor.execute('''SELECT name,astronomical FROM asteroids ,close_approach
where id=neo_reference_id
and astronomical<0.05''')
rec = cursor.fetchall()

dataset=rec
ds=pd.DataFrame(dataset)
ds
# Out:
#                 0         1
# 0      (2019 KK5)  0.026097
# 1       (2023 YR)  0.011564
# 2       (2024 AA)  0.004081
# 3      (2024 AQ1)  0.043829
# 4      (2023 YR1)  0.016608
# ...           ...       ...
# 3580   (2019 FY2)  0.032655
# 3581    (2025 HM)  0.038757
# 3582    (2025 HX)  0.009082
# 3583   (2025 HF1)  0.002634
# 3584  (2025 HO12)  0.010536
#
# [3585 rows x 2 columns]

# %% [markdown]
# Streamlit

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.49.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.45)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.3.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.49.1-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 58.2 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 94.4 MB/s eta 0:00:00
# Installing collected packages: pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.49.1

# %%
# !pip install streamlit-option-menu
# Out:
# Collecting streamlit-option-menu
#   Downloading streamlit_option_menu-0.4.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: streamlit>=1.36 in /usr/local/lib/python3.12/dist-packages (from streamlit-option-menu) (1.49.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.36->streamlit-option-menu) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (2.3.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.36->streamlit-option-menu) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit>=1.36->streamlit-option-menu) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit>=1.36->streamlit-option-menu) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit>=1.36->streamlit-option-menu) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (2025.8.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.36->streamlit-option-menu) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (0.27.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=1.36->streamlit-option-menu) (1.17.0)
# Downloading streamlit_option_menu-0.4.0-py3-none-any.whl (829 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.3/829.3 kB 9.9 MB/s eta 0:00:00
# Installing collected packages: streamlit-option-menu
# Successfully installed streamlit-option-menu-0.4.0

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.74.236.253

# %%
! streamlit run nasa_streamlit.py & npx localtunnel --port 8501
# Out:
# ⠙
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# ⠹⠸⠼⠴
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.48.147.249:8501
#
# ⠦⠧⠇⠏⠋your url is: https://two-shoes-divide.loca.lt
#   Stopping...
# ^C

# %%
# !pip install streamlit pyngrok
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.12/dist-packages (1.49.1)
# Collecting pyngrok
#   Downloading pyngrok-7.3.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.3.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading pyngrok-7.3.0-py3-none-any.whl (25 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.3.0

# %%
# 2. Write the app.py file
# %%writefile asteroid.py
import streamlit as st
import sqlite3
import pandas as pd
from datetime import date
import matplotlib.pyplot as plt

# ---------------- DB ----------------
conn = sqlite3.connect("mydb.db")

# ---------------- App ----------------
st.set_page_config(page_title="NASA Asteroid Tracker", layout="wide")

# ---------------- Sidebar CSS (Lucide styling for radio) ----------------
st.sidebar.markdown(
    """
    <style>
    /* Sidebar title */
    .sidebar-title{
        font-size:20px;font-weight:700;margin-bottom:14px;display:flex;align-items:center;color:white
    }
    .sidebar-title svg{width:22px;height:22px;margin-right:8px}

    /* Make radio look like our menu cards */
    .stRadio > div{display:flex;flex-direction:column;gap:10px}
    .stRadio [role="radiogroup"] > label{
        border:1px solid #444;border-radius:10px;padding:12px 14px;
        color:white;background:transparent;display:flex;align-items:center;
        gap:10px;cursor:pointer;transition:.15s ease-in-out
    }
    .stRadio [role="radiogroup"] > label:hover{background:#ff4d4d;color:white}
    .stRadio [role="radiogroup"] > label p{margin:0;font-weight:600}

    /* Hide default dot; keep the whole card clickable */
    .stRadio [role="radiogroup"] > label > div:first-child{display:none}

    /* Active (checked) state */
    .stRadio [role="radiogroup"] > label:has(input:checked){
        background:#ff4d4d;color:white;border-color:#ff4d4d;
    }

    /* Lucide icons for each radio option via CSS ::before */
    .stRadio [role="radiogroup"] > label::before{
        content:"";width:20px;height:20px;display:inline-block;
        background-repeat:no-repeat;background-position:center;background-size:contain;
        filter:invert(1); /* keep icons white on dark sidebar */
    }
    /* 1st item = app-window */
    .stRadio [role="radiogroup"] > label:nth-of-type(1)::before{
        background-image:url("data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' fill='none' stroke='white' stroke-width='2' viewBox='0 0 24 24'><rect x='3' y='4' width='18' height='16' rx='2'/><path d='M3 8h18'/></svg>");
    }
    /* 2nd item = sheet */
    .stRadio [role="radiogroup"] > label:nth-of-type(2)::before{
        background-image:url("data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' fill='none' stroke='white' stroke-width='2' viewBox='0 0 24 24'><rect x='3' y='4' width='18' height='16' rx='2'/><path d='M7 8h10M7 12h10M7 16h10'/></svg>");
    }
    </style>
    """,
    unsafe_allow_html=True
)

# ---------------- Sidebar Title (Lucide: laptop-minimal) ----------------
st.sidebar.markdown(
    """
    <div class='sidebar-title'>
      <svg xmlns="http://www.w3.org/2000/svg" fill="none" stroke="currentColor"
           stroke-width="2" viewBox="0 0 24 24">
        <rect x="3" y="4" width="18" height="12" rx="2"></rect>
        <path d="M2 20h20"></path>
      </svg>
      Asteroid Approaches
    </div>
    """,
    unsafe_allow_html=True
)

# ---------------- Sidebar Menu (works!) ----------------
options = ["Filter Criteria", "Queries"]
# preserve previous selection if present
default_idx = 0 if st.session_state.get("active_page", "Filter Criteria") == "Filter Criteria" else 1
menu = st.sidebar.radio("Menu", options, index=default_idx, label_visibility="collapsed")
st.session_state.active_page = menu

# ---------------- Title ----------------
st.markdown("<h1 style='text-align:center'>🚀 NASA Asteroid Tracker 🪐</h1>", unsafe_allow_html=True)

# ---------- Data helper ----------
@st.cache_data
def load_data():
    df = pd.read_sql("""
        SELECT *
        FROM asteroids
        JOIN close_approach ON asteroids.id = close_approach.neo_reference_id
    """, conn)
    for c in df.columns:
        if pd.api.types.is_numeric_dtype(df[c]): df[c] = df[c].fillna(0)
        else: df[c] = df[c].fillna("")
    df = df.convert_dtypes()
    for c in df.columns:
        if pd.api.types.is_integer_dtype(df[c]): df[c] = df[c].astype("int64", errors="ignore")
        elif pd.api.types.is_float_dtype(df[c]): df[c] = df[c].astype("float64", errors="ignore")
        else: df[c] = df[c].astype(str)
    return df

# ---------------- Pages ----------------
if menu == "Filter Criteria":
    df_all = load_data()
    filters = {}


    # Row 1
    c1, c2, c3 = st.columns([1,1,1], gap="medium")
    with c1:
        if "absolute_magnitude_h" in df_all.columns:
            lo, hi = float(df_all["absolute_magnitude_h"].min()), float(df_all["absolute_magnitude_h"].max())
            filters["absolute_magnitude_h"] = st.slider("Min Magnitude", lo, hi, (lo, hi), key="mag")
    with c2:
        if "relative_velocity_kmph" in df_all.columns:
            lo, hi = float(df_all["relative_velocity_kmph"].min()), float(df_all["relative_velocity_kmph"].max())
            filters["relative_velocity_kmph"] = st.slider("Relative Velocity (kmph)", lo, hi, (lo, hi), key="vel")
    with c3:
        start_date = st.date_input("Start Date", date(2024, 1, 1), key="start_date")

    # Row 2
    c4, c5, c6 = st.columns([1,1,1], gap="medium")
    with c4:
        if "estimated_diameter_min_km" in df_all.columns:
            lo, hi = float(df_all["estimated_diameter_min_km"].min()), float(df_all["estimated_diameter_min_km"].max())
            filters["estimated_diameter_min_km"] = st.slider("Min Estimated Diameter (km)", lo, hi, (lo, hi), key="diam_min")
    with c5:
        if "astronomical" in df_all.columns:
            lo, hi = float(df_all["astronomical"].min()), float(df_all["astronomical"].max())
            filters["astronomical"] = st.slider("Astronomical Unit", lo, hi, (lo, hi), key="au")
    with c6:
        end_date = st.date_input("End Date", date(2025, 12, 31), key="end_date")

    # Row 3
    c7, c8 = st.columns([2,1], gap="medium")
    with c7:
        if "estimated_diameter_max_km" in df_all.columns:
            lo, hi = float(df_all["estimated_diameter_max_km"].min()), float(df_all["estimated_diameter_max_km"].max())
            filters["estimated_diameter_max_km"] = st.slider("Max Estimated Diameter (km)", lo, hi, (lo, hi), key="diam_max")
    with c8:
        hazardous = st.selectbox("Potentially Hazardous", ["All", "Yes", "No"], key="hazard")

    st.markdown("<br>", unsafe_allow_html=True)

    if st.button("Filter", use_container_width=True):
        q = """
            SELECT *
            FROM asteroids
            JOIN close_approach ON asteroids.id = close_approach.neo_reference_id
            WHERE 1=1
        """
        for col, (lo, hi) in filters.items():
            q += f" AND {col} BETWEEN {lo} AND {hi}"
        q += f" AND close_approach_date BETWEEN '{start_date}' AND '{end_date}'"
        if hazardous == "Yes":
            q += " AND is_potentially_hazardous_asteroid = 1"
        elif hazardous == "No":
            q += " AND is_potentially_hazardous_asteroid = 0"

        df = pd.read_sql(q, conn)
        for c in df.columns:
            if pd.api.types.is_numeric_dtype(df[c]): df[c] = df[c].fillna(0)
            else: df[c] = df[c].fillna("")
        df = df.convert_dtypes()
        for c in df.columns:
            if pd.api.types.is_integer_dtype(df[c]): df[c] = df[c].astype("int64", errors="ignore")
            elif pd.api.types.is_float_dtype(df[c]): df[c] = df[c].astype("float64", errors="ignore")
            else: df[c] = df[c].astype(str)

        st.subheader("📊 Filtered Asteroids")
        if df.empty:
            st.warning("⚠️ No asteroids found with the selected filters.")
        else:
            st.dataframe(df, width=1400)


else:  # Queries
    queries = {
        "Count how many times each asteroid has approached Earth": """
            SELECT name, count(orbiting_body) as approaches
            FROM asteroids ,close_approach
            WHERE id=neo_reference_id AND orbiting_body="Earth"
            GROUP BY id
        """,

        "Average velocity of each asteroid over multiple approaches": """
            SELECT name, avg(DISTINCT relative_velocity_kmph) as avg_velocity
            FROM asteroids ,close_approach
            WHERE id=neo_reference_id
            GROUP BY id
        """,

        "Top 10 fastest asteroids": """
            SELECT * FROM (
                SELECT name, relative_velocity_kmph,
                dense_rank() OVER (ORDER BY relative_velocity_kmph DESC) rk
                FROM asteroids ,close_approach
                WHERE id=neo_reference_id
            ) WHERE rk<=10
        """,

        "Hazardous asteroids with >3 approaches to Earth": """
            SELECT name, count(is_potentially_hazardous_asteroid) as times
            FROM asteroids ,close_approach
            WHERE id=neo_reference_id
            AND orbiting_body="Earth"
            AND is_potentially_hazardous_asteroid=1
            GROUP BY id
            HAVING count(is_potentially_hazardous_asteroid)>3
        """,

        "Month with most asteroid approaches": """
            SELECT strftime('%Y-%m', close_approach_date) as month,
                   count(DISTINCT name) as approaches
            FROM asteroids ,close_approach
            WHERE id=neo_reference_id
            GROUP BY strftime('%Y-%m', close_approach_date)
            ORDER BY approaches DESC
            LIMIT 1
        """,

        "Fastest ever approach speed": """
            SELECT name, max(relative_velocity_kmph) as max_speed
            FROM asteroids ,close_approach
            WHERE id=neo_reference_id
        """,

        "Asteroids by maximum estimated diameter": """
            SELECT name, estimated_diameter_min_km, estimated_diameter_max_km
            FROM asteroids
            ORDER BY estimated_diameter_min_km DESC
        """,

        "Closest approach to Earth (date & distance)": """
            SELECT name, close_approach_date, miss_distance_km
            FROM asteroids ,close_approach
            WHERE id=neo_reference_id
            AND orbiting_body="Earth"
            ORDER BY miss_distance_km ASC
            LIMIT 10
        """,

        "Asteroids with velocity > 50,000 km/h": """
            SELECT name, relative_velocity_kmph
            FROM asteroids ,close_approach
            WHERE id=neo_reference_id
            AND orbiting_body="Earth"
            AND relative_velocity_kmph>50000
        """,

        "Approaches per month": """
            SELECT strftime('%m', close_approach_date) as month,
                   count(DISTINCT name) as approaches
            FROM asteroids ,close_approach
            WHERE id=neo_reference_id
            GROUP BY strftime('%m', close_approach_date)
        """,

        "Asteroid with highest brightness (lowest magnitude)": """
            SELECT name, min(absolute_magnitude_h) as brightness
            FROM asteroids
        """,

        "Hazardous vs Non-hazardous asteroids": """
            SELECT count(DISTINCT name) as count,"Non-hazardous" as type
            FROM asteroids
            WHERE is_potentially_hazardous_asteroid=0
            UNION
            SELECT count(DISTINCT name) as count,"Hazardous" as type
            FROM asteroids
            WHERE is_potentially_hazardous_asteroid=1
        """,

        "Asteroids closer than the Moon (<1 LD)": """
            SELECT name, close_approach_date, miss_distance_lunar
            FROM asteroids ,close_approach
            WHERE id=neo_reference_id AND miss_distance_lunar<1
        """,

        "Asteroids within 0.05 AU": """
            SELECT name, astronomical
            FROM asteroids ,close_approach
            WHERE id=neo_reference_id AND astronomical<0.05
        """
    }

    # Dropdown automatically triggers query
    choice = st.selectbox("Choose a query", list(queries.keys()))

    # Run selected query immediately
    q = queries[choice]
    df = pd.read_sql(q, conn)

    if df.empty:
        st.warning("⚠️ No results for this query.")
    else:
        st.subheader(f"📊 Results: {choice}")
        st.dataframe(df, width=1400)
# Out:
# Overwriting asteroid.py

# %%
# 3. Run Streamlit app with ngrok
from pyngrok import ngrok

# Kill old tunnels if any
ngrok.kill()

# Start new tunnel
public_url = ngrok.connect(8501)
print("👉 Streamlit app is live at:", public_url)

# !streamlit run asteroid.py --server.port 8501 & sleep 3
# Out:
# 👉 Streamlit app is live at: NgrokTunnel: "https://9c75509eb7e7.ngrok-free.app" -> "http://localhost:8501"
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.74.236.253:8501

# %%
# !ngrok config add-authtoken 32MLV8qlH8ujGxgh9X9O6c2feWr_76QTRbQe6fxSQYEPUd7bX
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
